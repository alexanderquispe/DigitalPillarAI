# %%
# Rmemeber projectid comes from prowerbi
# Rememmber projectid_api comes from website api

import pandas as pd
import ast
# Load the CSV file into a DataFrame
data = pd.read_csv('C:/Users/Alexander/Dropbox/pdfs_alex/row_data/countries_data.csv', encoding='latin1')

# Display the first few rows of the data
data
# Out:
#             id    last_modified_date                 admreg     admreg_key  \
# 0     34112367  2023-07-05T00:00:00Z  South Asia,South Asia  119231,119231
# 1     33836479  2022-06-06T00:00:00Z  South Asia,South Asia  119231,119231
# 2     33841647  2022-06-13T00:00:00Z  South Asia,South Asia  119231,119231
# 3     33813174  2022-05-10T00:00:00Z  South Asia,South Asia  119231,119231
# 4     32791172                   NaN  South Asia,South Asia  119231,119231
# ...        ...                   ...                    ...            ...
# 6288  19230244                   NaN  South Asia,South Asia  119231,119231
# 6289  17844507                   NaN  South Asia,South Asia  119231,119231
# 6290  14288042                   NaN  South Asia,South Asia  119231,119231
# 6291  14310094                   NaN  South Asia,South Asia  119231,119231
# 6292  13950344                   NaN  South Asia,South Asia  119231,119231
#
#                               authors        count count_key  \
# 0     {'0': {'author': 'World Bank'}}  Afghanistan     82662
# 1                                 NaN  Afghanistan     82662
# 2     {'0': {'author': 'World Bank'}}  Afghanistan     82662
# 3     {'0': {'author': 'World Bank'}}  Afghanistan     82662
# 4                                 NaN  Afghanistan     82662
# ...                               ...          ...       ...
# 6288                              NaN   South Asia    517212
# 6289                              NaN   South Asia    517212
# 6290                              NaN   South Asia    517212
# 6291                              NaN   South Asia    517212
# 6292                              NaN   South Asia    517212
#
#                                                   docna  \
# 0     {'0': {'docna': 'Afghanistan - Water Emergency...
# 1     {'0': {'docna': 'Afghanistan - Emergency Food ...
# 2     {'0': {'docna': 'Afghanistan  Health Emergenc...
# 3     {'0': {'docna': 'Afghanistan Community Resilie...
# 4     {'0': {'docna': 'Afghanistan - Early Warning, ...
# ...                                                 ...
# 6288  {'0': {'docna': 'Central Asia and South Asia -...
# 6289  {'0': {'docna': 'Nepal and India - Regional Tr...
# 6290  {'0': {'docna': 'South Asia - Nepal-India Elec...
# 6291  {'0': {'docna': 'Bhutan - Second Phase of the ...
# 6292  {'0': {'docna': 'Bangladesh, Nepal - Strengthe...
#
#                            docty  docty_key  ... no_of_pages  \
# 0     Project Appraisal Document     540656  ...         NaN
# 1     Project Appraisal Document     540656  ...         NaN
# 2     Project Appraisal Document     540656  ...         NaN
# 3     Project Appraisal Document     540656  ...         NaN
# 4     Project Appraisal Document     540656  ...        67.0
# ...                          ...        ...  ...         ...
# 6288  Project Appraisal Document     540656  ...       161.0
# 6289  Project Appraisal Document     540656  ...       108.0
# 6290  Project Appraisal Document     540656  ...       119.0
# 6291  Project Appraisal Document     540656  ...        81.0
# 6292  Project Appraisal Document     540656  ...       116.0
#
#                                                   sectr             sectr_key  \
# 0                                                   NaN                   NaN
# 1                                                   NaN                   NaN
# 2                                                   NaN                   NaN
# 3                                                   NaN                   NaN
# 4                                                   NaN                   NaN
# ...                                                 ...                   ...
# 6288              {'0': {'sector': '(Historic)Mining'}}                369171
# 6289  {'0': {'sector': 'Industry, Trade and Services...  647631,369163,369176
# 6290              {'0': {'sector': '(Historic)Mining'}}                369171
# 6291  {'0': {'sector': 'Agriculture, Fishing and For...         369180,369163
# 6292  {'0': {'sector': 'Agriculture, Fishing and For...         369180,369163
#
#                                                majtheme EnvironmentalCategory  \
# 0                                                   NaN                   NaN
# 1                                                   NaN                   NaN
# 2                                                   NaN                   NaN
# 3                                                   NaN                   NaN
# 4                                                   NaN                   NaN
# ...                                                 ...                   ...
# 6288  Environment and natural resource management,Tr...                     A
# 6289                              Trade and integration                   NaN
# 6290                                                NaN                   NaN
# 6291                                                NaN                   NaN
# 6292                                                NaN                   NaN
#
#      credit_no colti ml_abstracts alt_title src_cit
# 0          NaN   NaN          NaN       NaN     NaN
# 1          NaN   NaN          NaN       NaN     NaN
# 2          NaN   NaN          NaN       NaN     NaN
# 3          NaN   NaN          NaN       NaN     NaN
# 4          NaN   NaN          NaN       NaN     NaN
# ...        ...   ...          ...       ...     ...
# 6288     CRDNM   NaN          NaN       NaN     NaN
# 6289       NaN   NaN          NaN       NaN     NaN
# 6290       NaN   NaN          NaN       NaN     NaN
# 6291       NaN   NaN          NaN       NaN     NaN
# 6292       NaN   NaN          NaN       NaN     NaN
#
# [6293 rows x 78 columns]

# %%
data = data.rename(columns={'projectid': 'projectid_api'})

# %%
# Test for duplicates 
duplicate_rows = data[data['projectid_api'].duplicated(keep=False)]
duplicate_rows.available_in.unique()
duplicate_counts = data['projectid_api'].value_counts()
multiple_matches = duplicate_counts[duplicate_counts > 1]
print(multiple_matches)
# Out:
# P179267                                            5
# P174485                                            5
# P154839,P154840,P155257,P155256,P155542,P147839    5
# P151783,P131655,P151754,P151760,P151777,P151780    5
# P075776                                            5
#                                                   ..
# P128654                                            2
# P159515                                            2
# P116919                                            2
# P102177                                            2
# P116974                                            2
# Name: projectid_api, Length: 498, dtype: int64

# %%
# Clean data 
data = data[data["lang"] == "English"]
data = data.sort_values(by='docdt')
data = data.drop_duplicates(subset='projectid_api', keep='first')
data
# Out:
#             id    last_modified_date  \
# 543     696133                   NaN
# 1519    695002                   NaN
# 4609    694954                   NaN
# 939     694948                   NaN
# 3250    694946                   NaN
# ...        ...                   ...
# 3193  34112390  2023-07-05T00:00:00Z
# 2818  34104594  2023-07-20T00:00:00Z
# 0     34112367  2023-07-05T00:00:00Z
# 6203  34113345  2023-07-21T00:00:00Z
# 5906  34125924  2023-07-28T00:00:00Z
#
#                                                  admreg       admreg_key  \
# 543                                       Africa,Africa    119222,119222
# 1519  Latin America & Caribbean,Latin America & Cari...    119228,119228
# 4609  Middle East and North Africa,Middle East and N...    119229,119229
# 939   Latin America & Caribbean,Latin America & Cari...    119228,119228
# 3250                              South Asia,South Asia    119231,119231
# ...                                                 ...              ...
# 3193                              South Asia,South Asia    119231,119231
# 2818  Eastern and Southern Africa,Eastern and Southe...  1927319,1927319
# 0                                 South Asia,South Asia    119231,119231
# 6203        East Asia and Pacific,East Asia and Pacific    119225,119225
# 5906  Latin America & Caribbean,Latin America & Cari...    119228,119228
#
#                               authors  \
# 543                               NaN
# 1519                              NaN
# 4609                              NaN
# 939                               NaN
# 3250                              NaN
# ...                               ...
# 3193  {'0': {'author': 'World Bank'}}
# 2818  {'0': {'author': 'World Bank'}}
# 0     {'0': {'author': 'World Bank'}}
# 6203  {'0': {'author': 'World Bank'}}
# 5906  {'0': {'author': 'World Bank'}}
#
#                                                   count  \
# 543                                        Burkina Faso
# 1519                                           Colombia
# 4609                                 West Bank and Gaza
# 939                                              Belize
# 3250                                          Sri Lanka
# ...                                                 ...
# 3193                                          Sri Lanka
# 2818  Eastern and Southern Africa,Ethiopia,Djibouti,...
# 0                                           Afghanistan
# 6203                                    Pacific Islands
# 5906                                   St Maarten,World
#
#                                    count_key  \
# 543                                    82677
# 1519                                   82629
# 4609                                   82715
# 939                                    82655
# 3250                                   82538
# ...                                      ...
# 3193                                   82538
# 2818  1927319,82611,82637,82558,82686,517193
# 0                                      82662
# 6203                                  517200
# 5906                          1666031,517191
#
#                                                   docna  \
# 543   {'0': {'docna': 'Burkina Faso - Post-Primary E...
# 1519  {'0': {'docna': 'Colombia - Regulatory Reform ...
# 4609  {'0': {'docna': 'West Bank and Gaza - Communit...
# 939   {'0': {'docna': 'Belize - Social Investment Fu...
# 3250  {'0': {'docna': 'Sri Lanka - Energy Services D...
# ...                                                 ...
# 3193  {'0': {'docna': 'Sri Lanka - Public Financial ...
# 2818  {'0': {'docna': 'Djibouti, Ethiopia, Kenya, So...
# 0     {'0': {'docna': 'Afghanistan - Water Emergency...
# 6203  {'0': {'docna': 'Pacific Islands - Forum Fishe...
# 5906  {'0': {'docna': 'Sint Maarten - Improving Ment...
#
#                            docty  docty_key  ... no_of_pages  \
# 543   Project Appraisal Document     540656  ...        50.0
# 1519  Project Appraisal Document     540656  ...        32.0
# 4609  Project Appraisal Document     540656  ...        38.0
# 939   Project Appraisal Document     540656  ...        42.0
# 3250  Project Appraisal Document     540656  ...        58.0
# ...                          ...        ...  ...         ...
# 3193  Project Appraisal Document     540656  ...         NaN
# 2818  Project Appraisal Document     540656  ...         NaN
# 0     Project Appraisal Document     540656  ...         NaN
# 6203  Project Appraisal Document     540656  ...         NaN
# 5906  Project Appraisal Document     540656  ...         NaN
#
#                                                   sectr  \
# 543                      {'0': {'sector': 'Education'}}
# 1519  {'0': {'sector': 'Information and Communicatio...
# 4609         {'0': {'sector': '(Historic)Multisector'}}
# 939   {'0': {'sector': '(Historic)Health and other s...
# 3250           {'0': {'sector': '(Historic)Oil & Gas'}}
# ...                                                 ...
# 3193                                                NaN
# 2818                                                NaN
# 0                                                   NaN
# 6203                                                NaN
# 5906                                                NaN
#
#                         sectr_key  \
# 543                        369165
# 1519  369164,369179,647629,369163
# 4609                       369170
# 939                        647630
# 3250                       369167
# ...                           ...
# 3193                          NaN
# 2818                          NaN
# 0                             NaN
# 6203                          NaN
# 5906                          NaN
#
#                                                majtheme EnvironmentalCategory  \
# 543                                                 NaN                   NaN
# 1519  Financial and private sector development,Rule ...                   NaN
# 4609                                                NaN                   NaN
# 939                                                 NaN                   NaN
# 3250                                                NaN                   NaN
# ...                                                 ...                   ...
# 3193                                                NaN                   NaN
# 2818                                                NaN                     A
# 0                                                   NaN                   NaN
# 6203                                                NaN                   NaN
# 5906                                                NaN                   NaN
#
#       credit_no                                  colti ml_abstracts alt_title  \
# 543        N007    World Development Sources, WDS 1996          NaN       NaN
# 1519        NaN  World Development Sources, WDS 1997-1          NaN       NaN
# 4609        NaN  World Development Sources, WDS 1997-1          NaN       NaN
# 939         NaN  World Development Sources, WDS 1997-1          NaN       NaN
# 3250  P949;2938  World Development Sources, WDS 1997-1          NaN       NaN
# ...         ...                                    ...          ...       ...
# 3193        NaN                                    NaN          NaN       NaN
# 2818        NaN                                    NaN          NaN       NaN
# 0           NaN                                    NaN          NaN       NaN
# 6203        NaN                                    NaN          NaN       NaN
# 5906        NaN                                    NaN          NaN       NaN
#
#      src_cit
# 543      NaN
# 1519     NaN
# 4609     NaN
# 939      NaN
# 3250     NaN
# ...      ...
# 3193     NaN
# 2818     NaN
# 0        NaN
# 6203     NaN
# 5906     NaN
#
# [5729 rows x 78 columns]

# %%
# check nan in projectid_api
total_count = data['projectid_api'].count()
total_count

data.projectid_api.nunique()
nan_rows = data[data['projectid_api'].isna()]
print(nan_rows)

# Drop rows where 'projectid_api' is NaN
data = data.dropna(subset=['projectid_api'])

# Verify that NaN rows are removed
nan_rows = data[data['projectid_api'].isna()]
print(nan_rows)
data.shape
# Out:
#           id last_modified_date  \
# 4134  437162                NaN
#
#                                                  admreg     admreg_key  \
# 4134  Latin America & Caribbean,Latin America & Cari...  119228,119228
#
#      authors      count count_key  \
# 4134     NaN  Nicaragua     82532
#
#                                                   docna  \
# 4134  {'0': {'docna': 'Nicaragua - Pension and Finan...
#
#                            docty  docty_key  ... no_of_pages  \
# 4134  Project Appraisal Document     540656  ...        53.0
#
#                              sectr sectr_key majtheme EnvironmentalCategory  \
# 4134  {'0': {'sector': 'Finance'}}    369166      NaN                   NaN
#
#      credit_no colti ml_abstracts alt_title src_cit
# 4134      3344   NaN          NaN       NaN     NaN
#
# [1 rows x 78 columns]
# Empty DataFrame
# Columns: [id, last_modified_date, admreg, admreg_key, authors, count, count_key, docna, docty, docty_key, owner, projn, subsc, trustfund, trustfund_key, theme, prdln, prdln_key, seccl, lang, lang_key, lndinstr, lndinstr_key, entityids, repnb, docdt, datestored, volnb, majdocty, majdocty_key, abstracts, display_title, disclosure_date, disclosure_type, pdfurl, txturl, listing_relative_url, url_friendly_title, new_url, ext_pub_date, disclstat, topicv3, docm_id, chronical_docm_id, publishtoextweb_dt, versiontyp, versiontyp_key, projectid_api, guid, origu, author_keys, available_in, fullavailablein, url, bdmdt, closedt, geo_region_mdks, subtopic, subtopic_key, teratopic, teratopic_key, keywd, geo_regions, geo_reg_key, repnme, loan_no, totvolnb, historic_topic, no_of_pages, sectr, sectr_key, majtheme, EnvironmentalCategory, credit_no, colti, ml_abstracts, alt_title, src_cit]
# Index: []
#
# [0 rows x 78 columns]
# (5728, 78)

# %% [markdown]
# ## Merge with data selected from powerbi

# %%
# Merge with Data restricted by powerbi
projectid_data = pd.read_csv('C:/Users/Alexander/Dropbox/pdfs_alex/row_data/projectid_fy_data.csv')
projectid_data.rename(columns={"Project_Project Id":"projectid", 
                               "Project Key Dates_Approval FY":"approval_fy"}, inplace=True)

# %%
projectid_data.projectid.nunique()
# Out:
# 5004

# %%
# Merge projectsid when they are part of compund id 
def custom_match(string):
    return projectid_data['projectid'].apply(lambda x: x in string)

data['matched_projectid'] = data['projectid_api'].apply(lambda y: projectid_data['projectid'][custom_match(y)].iloc[0] if any(custom_match(y)) else None)
merged_data = projectid_data.merge(data, left_on='projectid', right_on='matched_projectid', how='inner')
unmatched_rows = projectid_data[~projectid_data['projectid'].isin(merged_data['projectid'])]
# Out:
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14004/2073994000.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['matched_projectid'] = data['projectid_api'].apply(lambda y: projectid_data['projectid'][custom_match(y)].iloc[0] if any(custom_match(y)) else None)

# %%
merged_data
# Out:
#      projectid  approval_fy        id    last_modified_date  \
# 0      P174604         2021  32602939                   NaN
# 1      P176157         2021  33009513                   NaN
# 2      P169930         2021  32183253                   NaN
# 3      P176450         2021  33186335  2022-05-18T00:00:00Z
# 4      P176570         2021  33209045  2022-05-17T00:00:00Z
# ...        ...          ...       ...                   ...
# 2369   P177041         2023  34059117  2023-05-23T00:00:00Z
# 2370   P178715         2023  34010307  2023-05-11T00:00:00Z
# 2371   P173446         2023  33896814  2022-09-15T00:00:00Z
# 2372   P178362         2023  34018958  2023-04-18T00:00:00Z
# 2373   P178125         2023  33970233  2023-01-04T00:00:00Z
#
#                                                  admreg       admreg_key  \
# 0       Europe and Central Asia,Europe and Central Asia    119226,119226
# 1                               Africa East,Africa East  1927319,1927319
# 2           East Asia and Pacific,East Asia and Pacific    119225,119225
# 3                                         Africa,Africa    119222,119222
# 4                                                   NaN              NaN
# ...                                                 ...              ...
# 2369  Western and Central Africa,Western and Central...  1927320,1927320
# 2370    Europe and Central Asia,Europe and Central Asia    119226,119226
# 2371        East Asia and Pacific,East Asia and Pacific    119225,119225
# 2372  Western and Central Africa,Western and Central...  1927320,1927320
# 2373    Europe and Central Asia,Europe and Central Asia    119226,119226
#
#                               authors                     count count_key  \
# 0                                 NaN    Bosnia and Herzegovina     82710
# 1                                 NaN                Mozambique     82527
# 2                                 NaN                  Cambodia     82560
# 3                                 NaN  Central African Republic     82657
# 4                                 NaN        Yemen, Republic of     82699
# ...                               ...                       ...       ...
# 2369  {'0': {'author': 'World Bank'}}                      Mali     82550
# 2370  {'0': {'author': 'World Bank'}}                   Albania     82664
# 2371  {'0': {'author': 'World Bank'}}                 Indonesia     82599
# 2372  {'0': {'author': 'World Bank'}}             Cote d'Ivoire     82625
# 2373  {'0': {'author': 'World Bank'}}                Azerbaijan     82673
#
#                                                   docna  ...  \
# 0     {'0': {'docna': 'Bosnia and Herzegovina - Firm...  ...
# 1     {'0': {'docna': 'Mozambique - Northern Crisis ...  ...
# 2     {'0': {'docna': 'Cambodia - Road Connectivity ...  ...
# 3     {'0': {'docna': 'Central African Republic - Em...  ...
# 4     {'0': {'docna': 'Yemen - Emergency Human Capit...  ...
# ...                                                 ...  ...
# 2369  {'0': {'docna': 'Mali - Landscape Restoration ...  ...
# 2370  {'0': {'docna': 'Albania - Climate Resilience ...  ...
# 2371  {'0': {'docna': 'Indonesia - Global Environmen...  ...
# 2372  {'0': {'docna': 'Cote dIvoire - Inclusive Con...  ...
# 2373  {'0': {'docna': 'Azerbaijan - State and Peaceb...  ...
#
#                                                   sectr      sectr_key  \
# 0                 {'0': {'sector': 'Financial Sector'}}         369166
# 1     {'0': {'sector': 'Social Protection'}, '1': {'...  369175,369180
# 2                                                   NaN            NaN
# 3                   {'0': {'sector': 'Transportation'}}         369176
# 4     {'0': {'sector': 'Health'}, '1': {'sector': 'W...  369168,369179
# ...                                                 ...            ...
# 2369                                                NaN            NaN
# 2370                                                NaN            NaN
# 2371                                                NaN            NaN
# 2372                                                NaN            NaN
# 2373                                                NaN            NaN
#
#      majtheme EnvironmentalCategory credit_no colti ml_abstracts alt_title  \
# 0         NaN                   NaN       NaN   NaN          NaN       NaN
# 1         NaN                   NaN       NaN   NaN          NaN       NaN
# 2         NaN                   NaN       NaN   NaN          NaN       NaN
# 3         NaN                   NaN       NaN   NaN          NaN       NaN
# 4         NaN                   NaN       NaN   NaN          NaN       NaN
# ...       ...                   ...       ...   ...          ...       ...
# 2369      NaN                     A       NaN   NaN          NaN       NaN
# 2370      NaN                   NaN       NaN   NaN          NaN       NaN
# 2371      NaN                   NaN       NaN   NaN          NaN       NaN
# 2372      NaN                   NaN       NaN   NaN          NaN       NaN
# 2373      NaN                   NaN       NaN   NaN          NaN       NaN
#
#      src_cit matched_projectid
# 0        NaN           P174604
# 1        NaN           P176157
# 2        NaN           P169930
# 3        NaN           P176450
# 4        NaN           P176570
# ...      ...               ...
# 2369     NaN           P177041
# 2370     NaN           P178715
# 2371     NaN           P173446
# 2372     NaN           P178362
# 2373     NaN           P178125
#
# [2374 rows x 81 columns]

# %%
# Remeber that we could have one Projectid that could be part of two projectid 
duplicate_counts = merged_data['repnb'].value_counts()
multiple_matches = duplicate_counts[duplicate_counts > 1]
print(multiple_matches)
# Out:
# Series([], Name: repnb, dtype: int64)

# %%
# Projects with no pads
merged_data.repnb.nunique()
nan_rows = merged_data[merged_data['repnb'].isna()]
nan_rows["projectid"]
# Out:
# 512    P177040
# 545    P178143
# 581    P167795
# 596    P176589
# 598    P175592
# 615    P176548
# 673    P176272
# 694    P177239
# 705    P174867
# Name: projectid, dtype: object

# %%
# list of project id without any info in the API
unmatched_rows
# Out:
#      projectid  approval_fy
# 1      P176546         2021
# 4      P176216         2021
# 5      P175785         2021
# 6      P176304         2021
# 7      P176034         2021
# ...        ...          ...
# 4999   P181051         2026
# 5000   P174175         2027
# 5001   P180331         2026
# 5002   P149827         2026
# 5003   P500425         2026
#
# [2630 rows x 2 columns]

# %%
import time
import requests

start_time = time.time()

response = requests.get(merged_data['txturl'][0])
txt_content = response.text
#txt_content = "response.text"
# Simple tokenization using spaces and punctuation as delimiters
tokens = txt_content.split()

print(f"Estimated number of tokens: {len(tokens)}")
end_time = time.time()

print(f"Execution time: {end_time - start_time} seconds")
# Out:
# Estimated number of tokens: 36974
# Execution time: 1.2060201168060303 seconds

# %%
import time
import requests

start_time = time.time()

# Fetch the TXT from the web
response = requests.get(merged_data['txturl'][6])

# Check if the request was successful
if response.status_code == 200:
    # Convert the fetched content to a string
    txt_content = response.text
    
    # Print the text content
    print(txt_content)

else:
    print("Failed to retrieve the text.")

end_time = time.time()

print(f"Execution time: {end_time - start_time} seconds")
# Out:
#                                          FOR OFFICIAL USE ONLY
#                                                                                     Report No: PAD4569
#
#                              INTERNATIONAL DEVELOPMENT ASSOCIATION
#
#                                      PROJECT APPRAISAL DOCUMENT
#                                                    ON A
#                                       PROPOSED CREDIT
#                   IN THE AMOUNT OF EUR 8.3 MILLION (US$10 MILLION EQUIVALENT)
#
#                                             AND A
#                                        PROPOSED GRANT
#                    IN THE AMOUNT OF SDR 7 MILLION (US$10 MILLION EQUIVALENT)
#
#                                           AND A
#                GRANT FROM THE ENERGY SECTOR MANAGEMENT ASSISTANCE PROGRAM
#                                IN THE AMOUNT OF US$1 MILLION
#
#                                       TO THE UNION OF COMOROS
#
#                                                    FOR A
#       SUPPORT TO COVID-19 VACCINE PURCHASE AND HEALTH SYSTEM STRENGTHENING PROJECT
#
#                                               JUNE 30, 2021
#
#                                          UNDER THE
#                 COVID-19 STRATEGIC PREPAREDNESS AND RESPONSE PROGRAM (SPRP)
#
#                      USING THE MULTIPHASE PROGRAMMATIC APPROACH (MPA)
#                                   WITH A FINANCING ENVELOPE OF
#                  UP TO US$6 BILLION APPROVED BY THE BOARD ON APRIL 2, 2020 AND
#                 UP TO US$12 BILLION ADDITIONAL FINANCING APPROVED BY THE BOARD
#                                       ON OCTOBER 13, 2020
#
# Health, Nutrition and Population Global Practice
# Eastern and Southern Africa Region
#  This document has a restricted distribution and may be used by recipients only in the performance of
#  their official duties. Its contents may not otherwise be disclosed without World Bank authorization.
#
#
#
#
#                                                                                                         Official Use
#                    CURRENCY EQUIVALENTS
#
#
#             (Exchange Rate Effective May 31, 2021)
#
#                                          Comorian Franc
#                        Currency Unit =
#                                          (KMF)
#                                 US$1= EUR 0.82
#                                US$1 = SDR 0.69
#                                US$1 = KMF 404.00
#
#                          FISCAL YEAR
#                    January 1 - December 31
#
#
#
#
# Regional Vice President: Hafez M. H. Ghanem
#       Country Director: Idah Z. Pswarayi-Riddihough
#      Regional Director: Amit Dar
#      Practice Manager: Ernest E. Massiah
#      Task Team Leader: Maud Juquois
#
#
#
#
#                                                           Official Use
#  The World Bank
#  Support to COVID-19 Vaccine Purchase and Health System Strengthening Project (P175840)
#
#
#
#                               ABBREVIATIONS AND ACRONYMS
#
# AEFI             Adverse Event Following Immunization
# AF               Additional Financing
# AfDB             African Development Bank
# AUP              Agreed Upon Procedures
# AVATT            African Vaccine Acquisition Task Team
# BCC              Comoros Central Bank (Banque Centrale des Comores)
# BFP              World Bank Facilitated Procurement
# CDC              Center for Disease Control
# CEPI             Coalition for Epidemic Preparedness Innovations
# CERC             Contingent Emergency Response Component
# CHW              Community Health Workers
# COMPASS          COMores Projet Approche globale de renforcement du Système de Santé
#                  (Comprehensive Approach to Health System Strengthening Project)
# COVAX AMC        COVID-19 Vaccines Advanced Market Commitment
# COVAX            COVID-19 Vaccines Global Access
# COVID-19         Coronavirus Disease 2019
# CPF              Country Partnership Framework
# CSO              Civil Society Organisation
# DFIL             Disbursement and Financial Information Letter
# DHIS2            District Health Information Software 2
# DO               Development Objective
# DP               Development Partner
# DPO              Development Policy Operation
# DSA              Debt Sustainability Analysis
# DSSI             Debt Service Suspension Initiative
# EPI              Expanded Program for Immunization
# ESCP             Environmental and Social Commitment Plan
# ESF              Environmental and Social Framework
# ESMAP            Energy Sector Management Assistance Program
# ESMF             Environmental and Social Management Framework
# ESS              Environmental and Social Standard
# EUL              Emergency Use Listing
# FM               Financial Management
# FTCF             Fast Track COVID-19 Facility
# FY               Fiscal Year
# GAVI             GAVI, the Vaccine Alliance
# GBV              Gender-Based Violence
# GDP              Gross Domestic Product
# GoC              Government of the Union of Comoros
# GRM              Grievance Redress Mechanism
# GRS              Grievance Redress Service
# GWP              Global Warming Potential
# HCI              Human Capital Index
# HNP              Health, Nutrition, and Population
#
#
#
#
#                                                                                           Official Use
#  The World Bank
#  Support to COVID-19 Vaccine Purchase and Health System Strengthening Project (P175840)
#
#
#
# IA               Internal Auditor
# IBRD             International Bank for Reconstruction and Development
# IDA              International Development Association
# IFC              International Finance Corporation
# IFR              Interim unaudited Financial Report
# IHR              International Health Regulation
# HMIS             Health Management Information System
# IMF              International Monetary Fund
# INSEED           Institut Nationale de la Statistique et des Etudes Economiques et Démographiques
#                  (National Institute of Statistics and Economic and Demographic Studies)
# IPC              Infection Prevention and Control
# IPF              Investment Project Financing
# JEE              Joint External Evaluation
# LMP              Labor Management Procedures
# M&E              Monitoring and Evaluation
# MOH              Ministry of Health
# MPA              Multiphase Programmatic Approach
# MSME             Micro, Small and Medium Enterprise
# NCC              National Coordination Committee
# NCD              Non-communicable disease
# NCSD             National Council for Sustainable Development
# NDC              Nationally Determined Contribution
# NDVP             National Deployment and Vaccination Plan
# NGO              Non-Governmental Organization
# NMWMP            National Medical Waste Management Plan
# NTWG             National Technical Working Group
# OHS              Occupational Health and Safety
# PAD              Project Appraisal Document
# PCR              Polymerase Chain Reaction
# PDO              Project Development Objective
# PHC              Primary Health Care
# PIE              Post Introduction Evaluation
# PIM              Project Implementation Manual
# PIU              Project Implementation Unit
# PP               Project Paper
# PPA              Policy and Performance Action
# PPG              Public and Publicly Guaranteed
# PPSD             Project Procurement Strategy for Development
# PQ               Prequalification
# RCF              Rapid Credit Facility
# RFI              Rapid Financing Instrument
# RMNCAH-N         Reproductive, Maternal, Newborn, Child and Adolescent Health and Nutrition
# SAGE             Strategic Advisory Group of Experts on Immunization
# SDFP             Sustainable Development Finance Policy
# SEA-SH           Sexual Exploitation and Abuse and Sexual Harassment
# SEP              Stakeholder Engagement Plan
#
#
#
#
#                                                                                                     Official Use
#  The World Bank
#  Support to COVID-19 Vaccine Purchase and Health System Strengthening Project (P175840)
#
#
#
# SMT              System Management Tool
# SOE              Statement of Expenditures
# SOP              Standard Operating Procedures
# SPRP             Strategic Preparedness and Response Program, also known as Global COVID-19 MPA
# SRA              Stringent Regulatory Authorities
# SSA              Sub-Saharan Africa
# STEP             Systematic tracking of Exchanges in Procurement
# TB               Tuberculosis
# TF               Trust Fund
# UCCIA            Union des Chambres de Commerce, d’Industrie et d’Agriculture (Union of Chambers
#                  of Commerce, Industry and Agriculture)
# UNICEF           United Nations Children’s Fund
# VAC              Vaccine Approval Criteria
# VDDM             Vaccine Delivery and Distribution Manual
# VIRAT            Vaccine Introduction Readiness Assessment
# VRAF             Vaccine Readiness Assessment Framework
# WASH             Water Sanitation and Hygiene
# WB               World Bank
# WBG              World Bank Group
# WHO              World Health Organization
# WPAB             Work Plan and Annual Budget
#
#
#
#
#                                                                                                    Official Use
#          The World Bank
#          Support to COVID-19 Vaccine Purchase and Health System Strengthening Project (P175840)
#
#
#
#
#                                                                   TABLE OF CONTENTS
#     DATASHEET ................................................................................. Error! Bookmark not defined.
#     I.      PROGRAM CONTEXT ....................................................................................................... 8
#             A.   MPA Program Context .................................................................................................................. 8
#             B.   Updated MPA Program Framework.............................................................................................. 9
#             C.   Learning Agenda ......................................................................................................................... 10
#     II.     CONTEXT AND RELEVANCE ........................................................................................... 10
#             A.   Country context .......................................................................................................................... 10
#             B.   Sectoral and Institutional Context .............................................................................................. 12
#             C.   Relevance to Higher Level Objectives ......................................................................................... 25
#     III. PROJECT DESCRIPTION.................................................................................................. 26
#             A.   Development Objectives ............................................................................................................. 26
#             B.   Project Components ................................................................................................................... 27
#             C.   Project Beneficiaries ................................................................................................................... 34
#     IV. IMPLEMENTATION ARRANGEMENTS ............................................................................ 35
#             A.   Institutional and Implementation Arrangements ....................................................................... 35
#             B.   Results Monitoring and Evaluation Arrangements ..................................................................... 36
#             C.   Sustainability ............................................................................................................................... 36
#     V. PROJECT APPRAISAL SUMMARY ................................................................................... 36
#             A.   Technical, Economic and Financial Analysis................................................................................ 36
#             B.   Fiduciary ...................................................................................................................................... 39
#             C.   Legal Operational Policies ........................................................................................................... 41
#             D.   Environmental and Social Standards .......................................................................................... 41
#     VI. GRIEVANCE REDRESS SERVICES ..................................................................................... 46
#     VII. KEY RISKS ..................................................................................................................... 47
#     VIII. RESULTS FRAMEWORK AND MONITORING ................................................................... 50
#            ANNEX 1: Status of Vaccines as of June 2, 2021 ......................................................................... 58
#            ANNEX 2: Project Costs ............................................................................................................ 59
#            ANNEX 3: Implementation Arrangements and Support Plan ....................................................... 60
#            ANNEX 4: Adjustments to the Country Program in Response to COVID-19 .................................. 69
#
#
# .
#
#
#
#
#                                                                                                                                                                   Official Use
#          The World Bank
#          Support to COVID-19 Vaccine Purchase and Health System Strengthening Project (P175840)
#
#
#
#
# DATASHEET
#
# BASIC INFORMATION
# BASIC_INFO_TABLE
# Country(ies)                   Project Name
#
# Comoros                        Support to COVID-19 Vaccine Purchase and Health System Strengthening
#
# Project ID                     Financing Instrument         Environmental and Social Risk Classification
#
#                                Investment Project
# P175840                                                     Substantial
#                                Financing
#
#
# Financing & Implementation Modalities
#
# [✓] Multiphase Programmatic Approach (MPA)                    [✓] Contingent Emergency Response Component (CERC)
# [ ] Series of Projects (SOP)                                  [✓] Fragile State(s)
# [ ] Performance-Based Conditions (PBCs)                       [✓] Small State(s)
# [ ] Financial Intermediaries (FI)                             [ ] Fragile within a non-fragile Country
#
# [ ] Project-Based Guarantee                                   [ ] Conflict
#
# [ ] Deferred Drawdown                                         [✓] Responding to Natural or Man-made Disaster
# [ ] Alternate Procurement Arrangements (APA)                  [ ] Hands-on Enhanced Implementation Support (HEIS)
#
#
#
# Expected Project Approval        Expected Project Closing     Expected Program Closing Date
# Date                             Date
#
# 30-Jun-2021                      31-Mar-2025                  31-Mar-2025
#
# Bank/IFC Collaboration
# No
#
#
# MPA Program Development Objective
# The Program Development Objective is to prevent, detect and respond to the threat posed by COVID-19 and
# strengthen national systems for public health preparedness
#
# MPA Financing Data (US$, Millions)      Financing
#
#
#
#
#                                                                                                            Page 1 of 74
#                                                         The World Bank
#                                                         Support to COVID-19 Vaccine Purchase and Health System Strengthening Project (P175840)
#
#
#
# MPA Program Financing Envelope                                                                                                                   18,000.00
#
#
#
# Proposed Project Development Objective(s)
# This Project’s Development Objective is to support the Government of the Union of Comoros to acquire and deploy
# COVID-19 vaccines, to strengthen national systems for public health preparedness
#
# Components
#
# Component Name                                                                                                                      Cost (US$, millions)
#
# Vaccines and related supplies provision and deployment                                                                                            10.50
#
# Health system strengthening for a stronger COVID-19 response                                                                                      10.50
#
# Contingent Emergency Response Component (CERC)                                                                                                     0.00
#
# Organizations
#
# Borrower:                                                                        Government of the Union of Comoros
# Implementing Agency:                                                             Ministry of Health
#
#
# MPA FINANCING DETAILS (US$, Millions)
# MPA FINA NCI NG DET AILS (US$, Millions) Approve d
#
#
#
#
# Board Approved MPA Financing Envelope:                                                                    18,000.00
# MPA Program Financing Envelope:                                                                           18,000.00
#
#                                                      of which Bank Financing (IBRD):                      9,900.00
#                                                      of which Bank Financing (IDA):                       8,100.00
#
#                                                      of which other financing sources:                    0.00
#
#
#
# PROJECT FINANCING DATA (US$, Millions)
# FIN_SUMM_NEW
# SUMMARY                                                  -NewFin1
#
#
#
#
# Total Project Cost                                                                                                                                    21.00
#
# Total Financing                                                                                                                                       21.00
#
#                                                        of which IBRD/IDA                                                                              20.00
#
#                                                                                                                                                     Page 2 of 74
#                         The World Bank
#                         Support to COVID-19 Vaccine Purchase and Health System Strengthening Project (P175840)
#
#
#
# Financing Gap                                                                                                         0.00
#
#
# DETAILS   -NewFinEnh1
#
#
#
#
# World Bank Group Financing
#    International Development Association (IDA)                                                                       20.00
#         IDA Credit                                                                                                   10.00
#         IDA Grant                                                                                                    10.00
#
# Non-World Bank Group Financing
#
#    Trust Funds                                                                                                        1.00
#         Energy Sector Management Assistance Program                                                                   1.00
#
#
# IDA Resources (in US$, Millions)
#
#                                             Credit Amount        Grant Amount     Guarantee Amount          Total Amount
# Comoros                                              10.00                10.00                    0.00              20.00
#   National PBA                                       10.00                10.00                    0.00              20.00
#
# Total                                                10.00                10.00                    0.00              20.00
#
#
# Expected Disbursements (in US$, Millions)
#
# WB Fiscal
#                                                                                 2021    2022        2023    2024     2025
# Year
# Annual                                                                          0.00    11.00       5.00    4.00      1.00
# Cumulative                                                                      0.00    11.00      16.00   20.00     21.00
#
#
#
#  INSTITUTIONAL DATA
#
# Practice Area (Lead)                                                 Contributing Practice Areas
# Health, Nutrition & Population
#
# Climate Change and Disaster Screening
# This operation has been screened for short and long-term climate change and disaster risks
#
#
#                                                                                                                    Page 3 of 74
#            The World Bank
#            Support to COVID-19 Vaccine Purchase and Health System Strengthening Project (P175840)
#
#
#
#
#  SYSTEMATIC OPERATIONS RISK-RATING TOOL (SORT)
#
# Risk Category                                                                        Rating
# 1. Political and Governance                                                         ⚫ Substantial
#
# 2. Macroeconomic                                                                    ⚫ Low
#
# 3. Sector Strategies and Policies                                                   ⚫ Substantial
#
# 4. Technical Design of Project or Program                                           ⚫ Substantial
#
# 5. Institutional Capacity for Implementation and Sustainability                     ⚫ High
#
# 6. Fiduciary                                                                        ⚫ Substantial
#
# 7. Environment and Social                                                           ⚫ Substantial
#
# 8. Stakeholders                                                                     ⚫ Moderate
#
# 9. Other                                                                            ⚫ Substantial
#
# 10. Overall                                                                         ⚫ High
#
# Overall MPA Program Risk                                                            ⚫ High
#
#
# COMPLIANCE
#
# Policy
# Does the project depart from the CPF in content or in other significant respects?
# [ ] Yes    [✓] No
#
# Does the project require any waivers of Bank policies?
# [ ] Yes    [✓] No
#
#
#
#
#                                                                                                     Page 4 of 74
#            The World Bank
#            Support to COVID-19 Vaccine Purchase and Health System Strengthening Project (P175840)
#
#
#
#
# Environmental and Social Standards Relevance Given its Context at the Time of Appraisal
#
# E & S Standards                                                                             Relevance
#
# Assessment and Management of Environmental and Social Risks and Impacts                     Relevant
#
# Stakeholder Engagement and Information Disclosure                                           Relevant
#
# Labor and Working Conditions                                                                Relevant
#
# Resource Efficiency and Pollution Prevention and Management                                 Relevant
#
# Community Health and Safety                                                                 Relevant
#
# Land Acquisition, Restrictions on Land Use and Involuntary Resettlement                     Not Currently Relevant
#
# Biodiversity Conservation and Sustainable Management of Living Natural Resources            Not Currently Relevant
#
# Indigenous Peoples/Sub-Saharan African Historically Underserved Traditional Local           Not Currently Relevant
# Communities
# Cultural Heritage                                                                           Not Currently Relevant
#
# Financial Intermediaries                                                                    Not Currently Relevant
#
#
# NOTE: For further information regarding the World Bank’s due diligence assessment of the Project’s potential
# environmental and social risks and impacts, please refer to the Project’s Appraisal Environmental and Social Review
# Summary (ESRS).
#
# Legal Covenants
#
# Sections and Description
# Schedule II, Section 1, A, 2, (e): Not later than three (3) months after the Effective Date, the senior accountant,
# accountant, and the internal auditor referred to in sub-paragraph (c) of this paragraph shall have been recruited
# and appointed.
#
# Sections and Description
# Schedule II, Section 1, A, 2, (f): Not later than three (3) months after the Effective Date the deputy coordinator, the
# procurement specialist, the monitoring and evaluation specialist, the social mobilization specialist, the two social
# and environmental assistants, and the environmental specialist referred to in sub-paragraph (c) of this paragraph
# shall have been recruited and appointed.
#
#
#
#
#                                                                                                                  Page 5 of 74
#            The World Bank
#            Support to COVID-19 Vaccine Purchase and Health System Strengthening Project (P175840)
#
#
#
# Sections and Description
# Schedule II, Section 1, A, 2, (g): Not later than three (3) months after the Effective Date, an external auditor shall
# have been recruited and appointed recruited on the basis of terms of reference, qualifications, integrity and
# experience acceptable to the Association.
#
# Sections and Description
# Schedule II, Section 1, B, 2, (a): by no later than two (2) month after the Effective Date, prepare a draft work plan
# and budget for Project implementation, setting forth, inter alia: (i) a detailed description of the planned activities,
# including any proposed conferences and Training, under the Project for the period covered by the plan; (ii) the
# sources and proposed use of funds therefor; (iii) procurement and environmental and social safeguards
# arrangements therefor, as applicable; and (iv) responsibility for the execution of said Project activities, budgets,
# start and completion dates, outputs and monitoring indicators to track progress of each activity.
#
#
#
# Conditions
#
# Type                               Financing source            Description
# Disbursement                       IBRD/IDA                    Schedule II, Section III, B.(a): No withdrawal shall be
#                                                                made for payments made prior to the Signature Date,
#                                                                except that withdrawals up to an aggregate amount not
#                                                                to exceed SDR 2,800,000 may be made for payments
#                                                                made prior to this date but on or after April 10, 2021,
#                                                                for Eligible Expenditures under Category (1).
#
# Type                               Financing source            Description
# Disbursement                       IBRD/IDA                    Schedule II, Section III, B.(b): No withdrawal shall be
#                                                                made under Category (1), unless and until:
#                                                                (i) the PIM, including the VDDM, have been duly
#                                                                adopted in form and substance acceptable to the
#                                                                Association and in accordance with Section I.B of
#                                                                Schedule 2 to this Agreement; and
#                                                                (ii) the Recipient has prepared, consulted upon,
#                                                                disclosed and adopted the ESMF, the SEP, the LMP, and
#                                                                NMWMP all in form and substance acceptable to the
#                                                                Association and in accordance with the ESCP.
#
# Type                               Financing source            Description
# Disbursement                       IBRD/IDA                    Schedule II, Section III, B.(c): No withdrawal shall be
#                                                                made under Category (2), unless and until the PIM have
#                                                                been duly adopted in form and substance acceptable to
#
#                                                                                                                    Page 6 of 74
#           The World Bank
#           Support to COVID-19 Vaccine Purchase and Health System Strengthening Project (P175840)
#
#
#
#                                                         the Association and in accordance with Section I.B of
#                                                         Schedule 2 to this Agreement.
#
# Type                           Financing source         Description
# Effectiveness                  Trust Funds              Article 4, 4.01: This Agreement shall not become
#                                                         effective until evidence satisfactory to the Bank has
#                                                         been furnished to the Bank that the conditions
#                                                         specified below have been satisfied.
#                                                         (a) The execution and delivery of this Agreement on
#                                                         behalf of the Recipient have been duly authorized or
#                                                         ratified by all necessary governmental action.
#                                                         (b) The Financing Agreement has been executed and
#                                                         delivered and all conditions precedent to its
#                                                         effectiveness or to the right of the Recipient to make
#                                                         withdrawals under it have been fulfilled.
#
# Type                           Financing source         Description
# Disbursement                   IBRD/IDA                 Schedule II, Section III, B.(d): No withdrawal shall be
#                                                         made for Emergency Expenditures under Category (3),
#                                                         unless and until all of the following conditions have
#                                                         been met in respect of said expenditures:
#                                                         (i) (A) the Recipient has determined that an Eligible
#                                                         Crisis or Emergency has occurred, and has furnished to
#                                                         the Association a request to withdraw Financing
#                                                         amounts under Category (3); and (B) the Association
#                                                         has agreed with such determination, accepted said
#                                                         request and notified the Recipient thereof; and
#                                                         (ii) the Recipient has adopted the CERC Manual and
#                                                         Emergency Action Plan, in form and substance
#                                                         acceptable to the Association.
#
#
#
#
#                                                                                                          Page 7 of 74
#           The World Bank
#           Support to COVID-19 Vaccine Purchase and Health System Strengthening Project (P175840)
#
#
#
#                                                      I.     PROGRAM CONTEXT
#
# A. MPA Program Context
#
# 1.     This Project Appraisal Document (PAD) describes the response of Comoros under the coronavirus disease 2019
# (COVID-19) Strategic Preparedness and Response Program (SPRP) using the Multiphase Programmatic Approach
# (MPA), approved by the World Bank’s Board of Executive Directors on April 2, 2020 (PCBASIC0219761) with an overall
# Program financing envelope of up to US$6 billion, and the Additional Financing (AF) to the SPRP approved on October
# 13, 2020 of US$12 billion1. The primary objectives are to enable affordable and equitable access to COVID-19 vaccines,
# ensure effective vaccine deployment in Comoros through vaccination system strengthening, and to further strengthen
# preparedness and response activities. The purpose is to provide upfront financing to help the Government of the
# Union of Comoros (GoC) purchase and deploy COVID-19 vaccines that meet the World Bank's vaccine approval criteria
# (VAC),and to strengthen health systems necessary to successfully deploy them, and to prepare for the future. The
# proposed project will finance: (i) vaccine acquisition to immunize approximately 18.3 percent of the population to
# support national population coverage of 60 percent and (ii) additional vaccine acquisition for 15 percent population
# to increase national coverage above 60 percent and efficacy. Additional project support for immunization systems will
# help reach over 60 percent of the population with COVID-19 vaccinations, complementing support from the COVID-
# 19 Vaccines Global Access (COVAX) Facility and other partners. Project financing for COVID-19 vaccines will follow the
# World Bank's updated VAC as of April 16, 2021: (i) the vaccine has received regular or emergency licensure or
# authorization from at least one of the Stringent Regulatory Authorities (SRAs) identified by the World Health
# Organization (WHO) for vaccines procured and/or supplied under the COVAX Facility, as may be amended from time
# to time by WHO; or (ii) the vaccine has received WHO Prequalification (PQ) or WHO Emergency Use Listing (EUL) 2.
# Comoros is providing vaccines free of charge.
#
# 2.     The proposed project contributes directly to the development objective of the global MPA to prevent, detect
# and respond to the threat posed by COVID-19 and strengthen national systems for public health preparedness. It
# will focus on acquisition and deployment of COVID-19 vaccines, continuing the vaccination efforts initiated by the
# Government during the ongoing first campaign that started on April 10, 2021. The first campaign is targeting 20
# percent of the population which are considered the most vulnerable to COVID-19 infection. The project will support
# the scale up of this vaccination effort to 60 percent of the population. This is occurring in a rapidly evolving context
# where COVID-19 variants have emerged, new vaccines are coming on the market, and there is growing vaccine and
# vaccine brand hesitancy among the general population and health providers. Reaching herd immunity will require
# strengthening overall immunization capacity and health systems. Importantly, the operation seeks to reduce COVID-
# 19 vaccination defaulting and incomplete coverage, and leverage the demand for COVID-19 vaccination for adults.
# Supporting the Government’s efforts to implement the National Deployment and Vaccination Plan (NDVP), the project
# aligns with the World Bank’s crisis response support to COVID-19 in Comoros, and the World Bank Group’s (WBG)
# adjusted Country Partnership Framework (CPF) for Comoros (Report No.145699-KM).
#
#
#
#       1 Strategic Preparedness and Response Program (SPRP), also known as Global COVID-19 MPA. The World Bank approved a US$12 billion
#       WBG Fast Track COVID-19 Facility (FTCF or “the Facility”) to assist IBRD and IDA countries in addressing the global pandemic and its
#       impacts. Of this amount, US$6 billion came from IBRD/IDA and US$6 billion from the International Finance Corporation (IFC). The IFC
#       subsequently increased its contribution to US$8 billion, bringing the FTCF total to US$14 billion. The AF of US$12 billion (IBRD/IDA) was
#       approved on October 13, 2020 to support the purchase and deployment of vaccines as well as strengthening the related immunization
#       and health care delivery system.
#       2 WHO EUL is a risk-based procedure for assessing and listing by WHO of unlicensed vaccines, therapeutics, and in vitro diagnostics
#
#       with the aim of expediting the availability of these products to people affected by a declared public health emergency.
#                                                                                                                                     Page 8 of 74
#                   The World Bank
#                   Support to COVID-19 Vaccine Purchase and Health System Strengthening Project (P175840)
#
#
#
#                                                          Box 1: Summary of the proposed Project
#
#          What this project will finance:
#            - Vaccine acquisition for 18.3 percent population coverage (the COVAX Advanced Market Commitment
#                 (AMC) acquires vaccines for another 20 percent of population coverage) to support national population
#                 coverage of 60 percent.
#            - Additional vaccine acquisition for 15 percent population to increase national coverage above 60
#                 percent and efficacy (potential booster shots needed).
#            - Deployment costs for 60 percent population coverage (that is, deployment for vaccines procured with
#                 COVAX AMC funds and with IDA funds).
#            - Medium to long-term investments for strengthening immunization services and public health
#                 preparedness.
#
#          Vaccine prices, getting to 60 percent population coverage, and potential booster shots:
#             - Costs for vaccine acquisition are estimates at this stage. Actual prices paid will depend on international
#                 market prices at the time of acquisition.
#             - COVAX AMC and IDA will fund vaccines for 38.3 percent population coverage. The GoC aims for 60
#                 percent population coverage. The gap of 21.7 percent population coverage is closed by domestic
#                 resources and contributions from other development partners (such as donations from China).
#
#          IDA financing under this project may also be used for the procurement of booster shots when and if they
#          become available.
#
# B.      Updated MPA Program Framework
#
# 3.        Table 1 below highlights how this project fits into the total envelope of the MPA for IBRD and IDA.
#
#                                                             Table 1: MPA Program Framework
#                                                                                                        Estimated                    Estimated
#                                       Phase’s Proposed                 Estimated       Estimated                        Estimated
#                     Sequential or                           IPF, DPF                                   Other                        Environmental
#      Project ID                       Development                      IBRD Amount     IDA Amount                       Approval
#                     Simultaneous                            or PforR                                   Amount                       & Social Risk
#                                       Objective*                       (US$ million)   (US$ million)                    Date
#                                                                                                        (US$ million)3               Rating
#                                          To support the
#                                       Government of the
#                                        Union of Comoros
#                                          to acquire and
#                                        deploy COVID-19                                                                   30-Jun-
#      P175840         Simultaneous                             IPF          0.0             20.0            1.0                        Substantial
#                                           vaccines, to                                                                    2021
#                                       strengthen national
#                                        systems for public
#                                              health
#                                          preparedness.
#                                       Board Approved Financing
#                                                                           9,900           8,100           18,000
#                                       Envelope
#
#
# 4.   The Energy Sector Management Assistance Program (ESMAP) will provide US$1 million in co-financing to
# support the strengthening of climate-friendly investments for health facilities’ electricity. The grant will contribute
#
#
#           3   Other sources of financing: will provide US$1 million Trust Fund from ESMAP
#                                                                                                                                          Page 9 of 74
#             The World Bank
#             Support to COVID-19 Vaccine Purchase and Health System Strengthening Project (P175840)
#
#
#
# to the improvement of the electricity supply in health facilities in response to power cuts by the local electricity
# company and recurring breakdowns of electrical installations. This will significantly improve the quality of health
# services in the long term.
#
# C. Learning Agenda
#
# 5.    The proposed project under the MPA Program will support adaptive learning throughout the implementation,
# as well as from international organizations including the WHO, International Monetary Fund (IMF), Center for Disease
# Control (CDC), United Nations International Children's Emergency Fund (UNICEF), and others. The global MPA includes
# the following:
#
#   •    Forecasting: Modeling the progression of the pandemic, both in terms of new cases and deaths, as well as the
#        economic impact of disease outbreaks under different scenarios.
#   •    Technical: Cost and effectiveness assessments of prevention and preparedness activities; research may be
#        financed for the re-purposing of existing anti-viral drugs and development and testing of new antiviral drugs
#        and vaccines.
#   •    Supply chain approaches: Assessments may be financed on options for timely distribution of medicines and
#        other medical supplies.
#   •    Social behaviors: Assessments on the compliance and impact of social distancing measures under different
#        contexts.
#
#                                                    II.    CONTEXT AND RELEVANCE
#
# A. Country context
#
# 6.    The Union of Comoros is a small volcanic archipelago off the coasts of Mozambique and Madagascar. Home
# to the second most diverse coral reefs in the world after Indonesia. Comoros has about 1,800 square kilometers of
# land and a maritime Exclusive Economic Zone seventy times the size of its land area. About half of its 887,929
# population live on Grande Comore, the largest island, where the capital city Moroni is located. While the country is
# prone to natural disasters (tsunami, cyclones, seismic and volcanic activities), its capacity to respond to emergencies
# remains weak.
#
# 7.    Comoros’ development has been shaped by three defining characteristics. First, like other small and remote
# islands, the country faces the challenges of diseconomies of scale, highly concentrated markets, lack of competition
# and high costs of living. Second, Comoros is classified as a country affected by fragility, conflict, and violence4. Third,
# remittances exacerbate a consumption driven growth trajectory. Besides, limited physical infrastructure and
# maintenance in the tree islands has been one of the major barriers to sustainable economic growth and development.
# The vulnerability of infrastructures is amplified by the high frequency of natural and climate-related disasters.
#
# 8.   Human development in Comoros remains low. The Human Capital Index (HCI) 2020 value for Comoros is 0.405,
# meaning a child born in Comoros today will be 40 percent as productive when s/he grows up as s/he could be, if s/he
#
#
# 4 Comoros is on the World Bank’s FY21 List of Fragile and Conflict -Affected Situations. Comoros is among the small states, distant from most
# large economies. Comoros’ markets are small and fragmented, limiting the occurrence of economies of scale and making Comoros highly
# dependent on international trade. The country has had more than 20 successful/attempted military coups since independence in 1975 and
# modern institutions are still in the making. More than half of the population lives in areas considered ‘at-risk’ to the effects of climate change.
# 5 www.worldbank.org/humancapitalproject.
#
#                                                                                                                                       Page 10 of 74
#            The World Bank
#            Support to COVID-19 Vaccine Purchase and Health System Strengthening Project (P175840)
#
#
#
# enjoyed complete education and full health. Not only is this value lower than the average for lower-middle-income
# countries, it also places Comoros at the lower end of the global distribution (145th ranking out of 175 countries). The
# HCI has slightly declined since 2017 (0.41).
#
# Impact of the COVID-19 pandemic
#
# 9.    Trajectory of COVID-19 in Comoros. The first confirmed case of COVID-19 in Comoros was on April 30, 2020,
# and by May 4, 2020, the first death was announced. The first wave of the COVID-19 outbreak was contained, with only
# seven deaths reported by the authorities at the end of 2020. Since January 2021, the number of COVID-19 infections
# and deaths has risen sharply, likely due to the arrival of the virus strain first seen in South Africa (B. 1.351 variant). The
# number of cases surged in early January 2021 and reached a peak on January 28, 2021 (975). The number of new daily
# cases was at its highest value on February 3, 2021 (128). There has been a downward trend since then. As of June 22,
# 2021, out of a population of 921,129, the cumulative number of cases reached 3,915: 2,698 in Grande Comore, 710 in
# Anjouan and 507 in Mohéli. The authorities have reported 146 deaths so far.
#
# 10. Transmission channels to the economy. The pandemic is hurting Comoros’ economic growth via two main
# channels. First, through the direct impact of the outbreak as it temporarily decreases labor supply and weakens
# economic activity due to social distancing. Second, through demand and supply effects related to external trade and
# the disruption of international travel6. Contrary to what was previously expected, remittances from the diaspora have
# proven to be resilient despite the slowdown of economic growth in Europe (France in particular).
#
# 11. Impact on poverty and potential deepening of fragility. Job destruction and decline in labor earnings are
# affecting those working in trade, tourism and transport, in a context characterized by already high levels of
# unemployment (especially among the youths) and informality. Further disruptions of service delivery could have
# adverse effects on health and education, particularly on the poor who already have limited access to basic services
# such as water, sanitation, and electricity. A large reduction in household incomes could increase the possibility of
# social unrest. This could play out in different ways across the islands, given the heavy reliance of communities in
# Grande Comore on remittances, and of communities in Anjouan and Mohéli on trade, particularly between the islands.
# Comoros has been exposed to risks stemming from the tense relations between the Union Government and the islands
# Governments. Even though these tensions have since gone down, especially after the 2019 elections (that gave
# President Azali a clear five-year term in office), the socioeconomic impacts and hardships of the health and economic
# crisis could feed into pre-existing frustrations, undermining the already fragile social cohesion, and fuel unrest. In light
# ...
#  Monitored Program which started in December 2019 (the SMP was expected to take place in February 2021 but
#  was interrupted due to the current uncertainties and practical challenges for engaging with the authorities).
#
#  7. Debt sustainability. Since 2016, PPG external debt has significantly increased, with a WB/IMF’s DSA under
#  preparation largely expected to place Comoros in the category of high risk of debt distress. In addition to donor’s
#  project financing, debt was used mainly to finance infrastructure projects in the electricity, roads,
#  telecommunications, and tourism sectors. PPG external debt increased from 16.5 percent of GDP in 2016 to 25.9
#  of GDP in 2020 (with State Owned Enterprises’ guaranteed debt representing about 30 percent of the total
#  external debt). Even though this debt level is low by international standards, debt and debt service in proportion
#  to exports and government revenues are high. The last World Bank/IMF’s DSA (April 2020) classified Comoros as
#  in moderate risk of debt distress with limited fiscal space to absorb shocks. However, after the signing of a large
#  non-concessional loan (December 2020) and a slower than expected economic recovery from COVID-19, the DSA
#  under preparation is very likely to place Comoros in the category of high risk of debt distress.
#
#  8. Debt Service Suspension Initiative (DSSI) and Sustainable Development Finance Policy (SDFP). Comoros’
#  participation in the DSSI helped to contain debt increases and avoid further external debt arrears build-up. The
#  agreements with official creditors and IMF resulted in savings of about US$2.0 million in 2020.26 The DSSI was
#  extended to June 2021 with estimated savings for Comoros to reach US$2.1 million. As an IDA country currently
#  in moderate risk of debt distress, Comoros is subject to the SDFP, which foresees several Policy and Performance
#  Actions (PPAs) that contribute to addressing critical debt vulnerabilities. The PPAs under the SDFP for this fiscal
#  year (FY21) focus on debt sustainability by avoiding the increase of non-concessional debt, while improving the
#  efficiency of public investments, and strengthening debt transparency. The two PPAs are: PPA 1 contract no new
#  non-concessional debt in FY2021 (Government has breached this PPA by signing a PPP contract for an investment
#
#  25   WB, AfDB and Saudi Arabia provided their budget support in late 2020. The IMF disbursed its loan in April 2020.
#  26   Note that China and India did not participate in the DSSI for that period.
#
#                                                                                                                         Page 70 of 74
# The World Bank
# Support to COVID-19 Vaccine Purchase and Health System Strengthening Project (P175840)
#
#
#
#  infrastructure project in the tourism sector, which, due to its contractual terms, is considered as a non-
#  concessional loan); and PPA 2: publication of a semi-annual statistical bulletin on PPG debt on the BCC website.
#  For PPA1, two statistical bulletins have been already published (in July and September 2020) and the next one is
#  expected in February 2021.
#
#  Government response
#  9. The GoC has acted swiftly in response to the COVID-19 crisis to mitigate its economic and social impact.
#  Box 4 provides the Government’s response to support household and firms. Most of the health and additional
#  social expenditures were financed with donor support. Custom measures have so far focused on simplifying
#  custom clearance processes for medical and food products coming from international donors, and on decreasing
#  costs for the trade of basic food and medical supplies. The Government is also providing financial support to
#  cover staff salaries for State-Owned Enterprises that have been strongly impacted by the global health crisis (e.g.
#  the State-Owned Enterprise managing the airports). MSMEs were also given the possibility to beneficiate from
#  tax deferrals. In addition, the BCC has adopted measures to address financial sector vulnerabilities accentuated
#  by the pandemic. The BCC has already lowered the obligatory reserve requirements and has agreed with banks
#  to extend loan maturities to borrowers in hard-hit sectors (suspending the possible increase in non-performing
#  loans). The loan "grace period" will be granted exclusively to households and companies directly affected by the
#  COVID-19 pandemic on a case-by-case basis, according to the eligibility criteria defined by the BCC and the
#  Professional Association of Banks and Financial Institutions.
#
#  10. The Government has established a National Coordination Committee to respond to COVID-19 to monitor
#  the impact of the health crisis to and adjust policy response if necessary. The Committee is supported by an
#  economic sub-committee that includes the participation of the BCC, the INSEED and the Ministry of Foreign
#  Affairs. The UCCIA, an independent association representing the private sector, has also created a committee to
#  identify the difficulties encountered by private actors in the face of the pandemic and is producing briefing notes
#  to the Government on the development of the economic situation. WHO is also member and supporter of the
#  Committee in the scientific and management, communication and logistic sub-committees.
#
#  11. In response to the rapid increase of new COVID-19 cases since the beginning of this year, the Government
#  announced new measures to contain the second wave of the pandemic. Measures included a curfew from 8 pm
#  to 5 am, the closure of mosques, the prohibition of religious and cultural gatherings or festivities and the
#  suspension of regular court hearings. Schools and universities also closed and domestic commercial flights were
#  limited to one flight per day from Grande Comore and three per week from Anjouan. All passengers are required
#  to hold a negative PCR. Marine travel with Mayotte has also been suspended.
#
#  12. On January 13, 2021, the Government also announced a New Management and Coordination Framework
#  to deal with this second and stronger COVID-19 wave. The new organization is composed by two national bodies
#  - the high Inter-ministerial Council and the Coordination Committee – and Islands Units. The high Inter-ministerial
#  Council, composed by the President of Comoros, Ministries, and other government representatives, is meeting
#  once a week and is in charge of defining policy and mobilizing resources during the pandemic. The Coordination
#  Committee, composed by the MOH and health sector specialists, will be charged of operationalize COVID-19
#  measures, strategic interventions, planification of the vaccination strategy, among others.
#
#  13. The GoC launched on April 10, 2021 the COVID-19 national vaccination campaign. To date, Comoros has
#  received vaccines from China (Sinopharm: 100,000 doses) and COVAX (AstraZeneca: 12,000). For the initial phase
#
#                                                                                                        Page 71 of 74
# The World Bank
# Support to COVID-19 Vaccine Purchase and Health System Strengthening Project (P175840)
#
#
#
#  of the campaign (April 10-26), they administered 43,140 Sinopharm first shot (around 5 percent of the population
#  received a first dose). Second shots for these priority groups started in May. As of May 23, 2021 58,440 doses
#  were administered with 15,300 people being fully vaccinated (that is, around 2 percent of the population). Eight
#  percent of these doses were for health workers (4,711), 17.4 percent for older adults (10,170) and 16.8 percent
#  of doses to people with health conditions (9,799). Forty-one percent of the doses benefited women (23,814).
#  The campaign with AstraZeneca doses was initially planned to start in June, however the GoC has officially
#  announced on June 15, 2021 that those doses would not be used and they are being given back to COVAX to
#  benefit another country.
#                  Box 3.1: Measures to support households and firms during the COVID-19 Crisis
#
#
#
#    Central Bank measures:
#       •   In coordination with the banking sector, the BCC advised banks to reschedule debt obligations and freeze
#           banking fees for loans of companies and households impacted by the crisis (until end of August), decided
#           on a case-by-case basis and without having impact in the NPLs.
#
#       •   Reserve rate for banks reduced from 15 percent to 10 percent.
#    Government measures:
#       •   Gratuity of COVID-19 testing and associated medical treatment.
#       •   Customs duties and taxes reduced (30 percent to 10 percent) for food products, essential medicines as
#           well as hygiene products and materials that are not already subject to a preferential or reduced tax (until
#           end of December 2021).
#       •   Simplified procedures to allow fast clearing for the import of food and health products.
#       •   A tax deferral of 3 months ending September 30, 2020 for large firms and 9 months ending December
#           31, 2020 for MSME.
#       •   Envelope of CF100 million per month to public companies in the aviation sector (Com’Air Assistance,
#           Anacm and ADC) to support the payment of salaries whose activity has been interrupted by the closure
#           of the airports.
#       •   Bonus for public workers working in the health sector and in other COVID-19 response activities.
#       •   Establishment of a system of price controls for basic necessities supervised by the Ministry of the
#           Economy to monitor price increases and prevent unjustified inflation.
#       •   Prohibition on the National Company of Exploitation and Distribution of Water (SONEDE) and the
#           National Company of Electricity of Comoros (SONELEC) to cut water and electricity to households.
#
#
#
#
#                                                                                                        Page 72 of 74
# The World Bank
# Support to COVID-19 Vaccine Purchase and Health System Strengthening Project (P175840)
#
#
#
#             WBG support for responding to the crisis
#
#  14. The World Bank country program’s health response to COVID-19 is as follows:
#      CERC of the COMPASS Project (US$30 million, P166013), activated in April 2020 and replenished by AF of US$5
#      million, as requested by Government.
#
#  15. In addition to supporting the health response, the World Bank country program has been adjusted to focus
#  on:
#      (i)      Protecting the poor and vulnerable. Existing Social Safety Net Project – the scope of the Additional
#               Financing (US$18 million, P171633), geared to bring economic recovery and resilience to the poorest
#               families who were hit by the Cyclone Kenneth, will be widened to include the urban poorest
#               households hit by COVID economic impact or by quarantine/lockdown measures as requested by the
#               Government. Unconditional cash transfers related to COVID-19 under this Social Safety Net Project
#               are planned at US$6 million. Restructuring of the project was carried out in June 2020 and the
#               replenishment has been done during the FY21. A second AF to the Safety Net Project (US$6 million,
#               P174866) was also delivered in FY21 to cover financing gap.
#
#      (ii)      Accelerating recovery and strengthening economic resilience. Emergency DPO for COVID-19
#                Response (P174260, US$10 million). The Emergency DPO contributed to support the Government’s
#                immediate relief response to the social and economic impacts of the COVID-19 crisis, whilst increasing
#                future resilience by supporting longer term structural measures. The program is organized around
#                three pillars. The first pillar (“Protecting the Poor & Vulnerable”) aims to facilitate cross-border trade
#                and reduce the price of medical supplies and essential food products and to enhance the coordination
#                of safety net programs and rapid implementation of future interventions. The second pillar (“Ensuring
#                Sustainable Business Growth & Job Creation”) seeks to support the economic recovery by granting tax
#                deferrals to MSMEs and self-employed (for example, lawyers, notaries and doctors) and facilitate
#                mobile banking and mobile payments to incentivize financial development and inclusion. The third
#                pillar (“Strengthening Policies, Institutions and Investments for Rebuilding Better”) includes measures
#                to improve debt transparency and a first step in the restructuring process of a systemic bank.
#
#  16. In summary, this would imply additional financing of a total of US$20 million, being US$5 million for COVID
#  health emergency (through the COMPASS CERC); US$10 million for Emergency DPO; and US$6 million as social
#  safety net to poor households. In FY22 and FY23, the CPF will focus on the delivery of infrastructure; nutrition
#  and women empowerment programs that will support the recovery efforts from COVID-19 and lay the
#  foundation for Comoros to get back on its growth trajectory with the aim of building better a more resilient and
#  inclusive economy.
#
#
#
#
#                                                                                                            Page 73 of 74
# The World Bank
# Support to COVID-19 Vaccine Purchase and Health System Strengthening Project (P175840)
#
#
#
#                                   Table 4.1. World Bank’s response to COVID-19
#
#             Themes                  Phase: I Relief                             Amount Delivery
#             Portfolio Adjustment
#             Themes                  Project name                                Amount Board date
#             Program to be delivered
#                                     Activation of the CERC/AF to COMPASS
#             1. Health response      (P166013)                                   5          Aug-20
#             2. Social response      Restructuring and Reallocation of the
#                                     AF Social Protection Project (P171633)      6          June-20
#             3. Strengthening
#             policies
#                                     Emergency DPO (P174260)                     10         Dec-20
#                                     Total                                       21
#
#          Selectivity, complementarity, partnerships
#
#  17. Consultations and collaboration with DPs have been effective since the outbreak of the COVID-19
#  pandemic, and also for COVID-19 vaccination. Through the Development Partners Forum (FPAD), the World
#  Bank participates actively in the formulation of a coordinated response to COVID-19 among DPs. On the budget
#  support emergency measures, the DPO operation was coordinated with budget support programs from other
#  DPs (such as IMF, AfDB, Saudi Arabia and Morocco) and consultations were undertaken with the private sector
#  for the identification of policy reforms. The World Bank had continuous discussions with the IMF Comoros
#  country team and contributed to the preparation of the IMF ‘s emergency support (RCF/RFI US$12.2 million,
#  equivalent to 50 percent of quota). The AfDB approved budget support operation in November 2020. The policy
#  recommendations underpinning the DPO operation’s prior actions were discussed with key DPs, some policy
#  reforms were also identified following a number of meetings with the private sector. A coordination effort was
#  also initiated by the World Bank regarding the technical preparation of the unconditional cash transfer response
#  to COVID-19. Finally, following the strong spread of the virus since the beginning of the year, the World Bank is
#  coordinating with the IMF and other donors to provide additional budget support.
#
#
#
#
#                                                                                                      Page 74 of 74
#
# Execution time: 1.927710771560669 seconds

# %% [markdown]
# ## Extracting using create_extraction_chain

# %%
# Run topic by topic
import pandas as pd
from PyPDF2 import PdfReader
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import ElasticVectorSearch, Pinecone, Weaviate, FAISS
import openai

import os
openai.api_key = "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"
os.environ["OPENAI_API_KEY"] = "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"

# %%
from enum import Enum
from pydantic import BaseModel, Field

# %%
from langchain.chat_models import ChatOpenAI
from langchain.chains import create_extraction_chain, create_extraction_chain_pydantic
from langchain.prompts import ChatPromptTemplate

# %%
from langchain.chat_models import ChatOpenAI
from langchain.chains import create_tagging_chain, create_tagging_chain_pydantic
from langchain.prompts import ChatPromptTemplate

# %% [markdown]
# ## Extract using veectors

# %%
pads_2014_2023 = merged_data.copy()

# %%
pads_2014_2023['pdfurl'][0]
# Out:
# 'http://documents.worldbank.org/curated/en/746421608001638858/pdf/Bosnia-and-Herzegovina-Firm-Recovery-and-Support-Project.pdf'

# %%
topics = f"""Digital infrastructure and broadband connectivity, 
digital public infrastructure and digital platforms,
digital financial services, digital industries, 
digital businesses, digital skills development, 
digital security measures."""

# %%
pads_2014_2023['repnb'][1]
# Out:
# 'PAD4389'

# %%
# Run topic by topic
import pandas as pd
from PyPDF2 import PdfReader
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import ElasticVectorSearch, Pinecone, Weaviate, FAISS
import openai

import os
openai.api_key = "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"
os.environ["OPENAI_API_KEY"] = "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"

# read data from the file and put them into a variable called raw_text
response = requests.get(pads_2014_2023['txturl'][0])
txt_content = response.text

text_splitter = CharacterTextSplitter(        
    separator = "\n",
    chunk_size = 1500,
    chunk_overlap  = 300,
    length_function = len,
)
texts = text_splitter.split_text(txt_content)

# Download embeddings from OpenAI
embeddings = OpenAIEmbeddings()

docsearch = FAISS.from_texts(texts, embeddings)

from langchain.chains.question_answering import load_qa_chain
from langchain.llms import OpenAI

chain = load_qa_chain(OpenAI(temperature=0), chain_type="stuff")

# construct the query
query = f"is the document about a digital project?"
#query = f"Does the document directly discuss any of the following topics: {topic}"
#query = f"Does the Project components section directly discuss any of the following topics: {topic}"

# perform the search and process the response
docs = docsearch.similarity_search(query)
response = chain.run(input_documents=docs, question=query)
print(response)
# Out:
#  Yes, the document is about a digital project. It discusses digital/tech solutions that mitigate restrictions imposed by the pandemic, such as e-commerce, cloud-based solutions, remote work solutions, automation, new procedures or processing methods leading to improving production and/or processing of higher quality, increasing/adapting IT and Financial Services, and programs promoting technology and digital adoption by MSMEs to increase productivity in the aftermath of COVID-19.

# %%
# construct the query
query = f"What are all the elements in the Project Components sections?"
# perform the search and process the response
docs = docsearch.similarity_search(query)
response = chain.run(input_documents=docs, question=query)
print(response)
# Out:
#  Power plant complex civil works, mechanical and electrical works, engineering, administration, and supervision costs.

# %%
# construct the query
query = f"How many elements are between the Project Components sections and Project Financing?"
# perform the search and process the response
docs = docsearch.similarity_search(query)
response = chain.run(input_documents=docs, question=query)
print(response)
# Out:
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised APIConnectionError: Error communicating with OpenAI: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)).
#  Three elements: Project Cost and Financing, PDO Level Results Indicators, and Project Description.

# %%
# construct the query
query = f"Extract all information about Project Component 1, without changes"
# perform the search and process the response
docs = docsearch.similarity_search(query)
response = chain.run(input_documents=docs, question=query)
print(response)
# Out:
#  Component A1 (IDA): Civil Works (US$ 177.0 million). This component will include the construction of the diversion/power canal, surface powerhouse, access roads and construction site facilities such as offices and housing.

# %% [markdown]
# # Test using Data from Clement

# %%
# Import data created from Clement
import pandas as pd 
file_path = "C:/Users/Alexander/Dropbox/pdfs_alex/row_data/DE4A Tier 1 IPF P4R, active and closed, 2018-2023, no AF.csv"
# Load the Excel file
clement_data = pd.read_csv(file_path)
clement_data.rename(columns={"Project Id": "projectid"}, inplace = True)
clement_data
# Out:
#     projectid  Digital Infrastructure  Digital Public Platforms  \
# 0     P148537                       0                         1
# 1     P150166                       0                         1
# 2     P154943                       0                         1
# 3     P156894                       1                         1
# 4     P159395                       1                         1
# ..        ...                     ...                       ...
# 122   P178563                       1                         1
# 123   P178609                       1                         0
# 124   P178658                       0                         0
# 125   P178801                       0                         1
# 126   P178824                       1                         1
#
#      Digital Financial Services  Digital Businesses  Digital Skills
# 0                             0                   0               0
# 1                             0                   0               1
# 2                             0                   0               0
# 3                             0                   0               0
# 4                             0                   0               0
# ..                          ...                 ...             ...
# 122                           0                   0               1
# 123                           0                   0               1
# 124                           1                   0               0
# 125                           0                   0               0
# 126                           0                   0               0
#
# [127 rows x 6 columns]

# %%
clement_dig_proj = pd.merge(clement_data, pads_2014_2023, on='projectid')
clement_dig_proj
# Out:
#    projectid  Digital Infrastructure  Digital Public Platforms  \
# 0    P148537                       0                         1
# 1    P154943                       0                         1
# 2    P156894                       1                         1
# 3    P159395                       1                         1
# 4    P160418                       1                         0
# ..       ...                     ...                       ...
# 87   P177947                       0                         1
# 88   P178176                       0                         1
# 89   P178339                       0                         1
# 90   P178609                       1                         0
# 91   P178824                       1                         1
#
#     Digital Financial Services  Digital Businesses  Digital Skills  \
# 0                            0                   0               0
# 1                            0                   0               0
# 2                            0                   0               0
# 3                            0                   0               0
# 4                            0                   0               0
# ..                         ...                 ...             ...
# 87                           1                   0               0
# 88                           1                   1               1
# 89                           0                   0               0
# 90                           0                   0               1
# 91                           0                   0               0
#
#     approval_fy        id    last_modified_date  \
# 0          2018  27883184                   NaN
# 1          2019  31019364                   NaN
# 2          2018  29773519                   NaN
# 3          2019  30719058                   NaN
# 4          2018  29885966                   NaN
# ..          ...       ...                   ...
# 87         2023  34063208  2023-05-16T00:00:00Z
# 88         2022  33789587  2022-04-18T00:00:00Z
# 89         2023  33878389  2022-08-23T00:00:00Z
# 90         2023  33937854  2022-12-07T00:00:00Z
# 91         2023  33940388  2022-11-18T00:00:00Z
#
#                                                admreg  ... credit_no colti  \
# 0     Europe and Central Asia,Europe and Central Asia  ...       NaN   NaN
# 1         East Asia and Pacific,East Asia and Pacific  ...       NaN   NaN
# 2                               South Asia,South Asia  ...       NaN   NaN
# 3         East Asia and Pacific,East Asia and Pacific  ...       NaN   NaN
# 4                                       Africa,Africa  ...       NaN   NaN
# ..                                                ...  ...       ...   ...
# 87  Western and Central Africa,Western and Central...  ...       NaN   NaN
# 88                                                NaN  ...       NaN   NaN
# 89  Latin America & Caribbean,Latin America & Cari...  ...       NaN   NaN
# 90  Latin America & Caribbean,Latin America & Cari...  ...       NaN   NaN
# 91  Middle East and North Africa,Middle East and N...  ...       NaN   NaN
#
#    ml_abstracts alt_title src_cit matched_projectid  digital_dummy  \
# 0           NaN       NaN     NaN           P148537           True
# 1           NaN       NaN     NaN           P154943           True
# 2           NaN       NaN     NaN           P156894           True
# 3           NaN       NaN     NaN           P159395          False
# 4           NaN       NaN     NaN           P160418           True
# ..          ...       ...     ...               ...            ...
# 87          NaN       NaN     NaN           P177947           True
# 88          NaN       NaN     NaN           P178176          False
# 89          NaN       NaN     NaN           P178339          False
# 90          NaN       NaN     NaN           P178609           True
# 91          NaN       NaN     NaN           P178824          False
#
#                                       abstracts_clean  \
# 0   The development objective of Modernization of ...
# 1   The development objective of Digital Governmen...
# 2   The objective of the Digital Central Asia Sout...
# 3   The development objective of Tuvalu Telecommun...
# 4   The objective of the E-Agriculture Project for...
# ..                                                ...
# 87  The development objective of the Second Financ...
# 88                                                NaN
# 89                                                NaN
# 90  The development objective of the Strengthening...
# 91  The development objective of Social Safety Net...
#
#                                       combined_column  \
# 0   The development objective of Modernization of ...
# 1   The development objective of Digital Governmen...
# 2   The objective of the Digital Central Asia Sout...
# 3   The development objective of Tuvalu Telecommun...
# 4   The objective of the E-Agriculture Project for...
# ..                                                ...
# 87  The development objective of the Second Financ...
# 88  {'0': {'keywd': 'small and medium enterprise; ...
# 89                                                NaN
# 90  The development objective of the Strengthening...
# 91  The development objective of Social Safety Net...
#
#                                         abstract_keyw
# 0   The development objective of Modernization of ...
# 1   The development objective of Digital Governmen...
# 2   The objective of the Digital Central Asia Sout...
# 3   The development objective of Tuvalu Telecommun...
# 4   The objective of the E-Agriculture Project for...
# ..                                                ...
# 87  The development objective of the Second Financ...
# 88  {'0': {'keywd': 'small and medium enterprise; ...
# 89                                                NaN
# 90  The development objective of the Strengthening...
# 91  The development objective of Social Safety Net...
#
# [92 rows x 90 columns]

# %%
import pandas as pd
import requests
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import FAISS
from langchain.chains.question_answering import load_qa_chain
from langchain.llms import OpenAI
import os

# Initialize API keys
openai.api_key = "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"
os.environ["OPENAI_API_KEY"] = "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"



def is_digital_project(url):
    
    topics = """Digital, Digital Technology, Digital infrastructure and broadband connectivity, 
    digital public infrastructure and digital platforms,
    digital financial services, digital industries, 
    digital businesses, digital skills development, 
    digital security measures."""

    print(f"Processing URL: {url}")
    # Fetch content from the URL
    try:
        response = requests.get(url)
    except Exception as e:
        print(f"Failed to fetch URL: {e}")
        return 404  # Returning 0 if the URL fetch fails
    
    txt_content = response.text
    
    # Split text
    text_splitter = CharacterTextSplitter(
        separator="\n",
        chunk_size=2000,
        chunk_overlap=300,
        length_function=len,
    )
    texts = text_splitter.split_text(txt_content)
    
    # Download embeddings from OpenAI
    embeddings = OpenAIEmbeddings()
    docsearch = FAISS.from_texts(texts, embeddings)
    
    # Load QA chain
    chain = load_qa_chain(OpenAI(temperature=0), chain_type="stuff")
    
    # Query
    # construct the query
    query = f"is the document discussing digital topics? and why?"
    #query = f"Does the document discuss any of the following topics: {topics}"
    print(query)
    #query = f"Does the Project components section direct
    docs = docsearch.similarity_search(query)
    response_text = chain.run(input_documents=docs, question=query)
    print(response)
    
    is_digital = 1 if 'yes' in response_text.lower() else 0
    
    return is_digital, response_text  # Assuming the response is a string

# %%
# Create a new column in your DataFrame
clement_dig_proj['digital_project_q1'] = clement_dig_proj['txturl'].apply(is_digital_project)
# Out:
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised APIConnectionError: Error communicating with OpenAI: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)).
# Created a chunk of size 1683, which is longer than the specified 1500
# Created a chunk of size 1571, which is longer than the specified 1500
# Created a chunk of size 1912, which is longer than the specified 1500
# Created a chunk of size 1762, which is longer than the specified 1500
# Created a chunk of size 1737, which is longer than the specified 1500
# Created a chunk of size 1647, which is longer than the specified 1500
# Created a chunk of size 1533, which is longer than the specified 1500
# Created a chunk of size 1580, which is longer than the specified 1500
# Created a chunk of size 1543, which is longer than the specified 1500
# Created a chunk of size 1701, which is longer than the specified 1500
# Created a chunk of size 1659, which is longer than the specified 1500
# Created a chunk of size 1781, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1767, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1805, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1767, which is longer than the specified 1500
# Created a chunk of size 1895, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1806, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1783, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1767, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1815, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1816, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1767, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1767, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1830, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1767, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1783, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1767, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1831, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1839, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1767, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1767, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1767, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1783, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1767, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1767, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1767, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1767, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1783, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1767, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1767, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1767, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1783, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1767, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1766, which is longer than the specified 1500
# Created a chunk of size 1766, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500

# %%
clement_dig_proj[clement_dig_proj['digital_project_q1']==0]["repnb"]
# Out:
# 3     PAD2696
# 15     126142
# 18    PAD3050
# 20    PAD3550
# 23    PAD3001
# 25    PAD2949
# 52    PAD3788
# 64    PAD4365
# 69    PAD4621
# 70    PAD4849
# 75     177898
# 84    PAD4876
# 85    PAD4840
# 88    PAD4960
# 89    PAD4944
# 91    PP5074
# Name: repnb, dtype: object

# %%
result_5 = clement_dig_proj[clement_dig_proj['repnb']=="PAD2371"]['txturl'].apply(is_digital_project)

# %%
clement_dig_proj[clement_dig_proj['digital_project_q1']==0]['txturl'].apply(is_digital_project)
# Out:
# Processing URL: http://documents.worldbank.org/curated/en/771141548558042678/text/Tuvalu-project-appraisal-document-pad-P159395Dec18-12182018-636841368206528813.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because the World Bank is actively engaged on the digital development agenda in the Pacific and is working to facilitate improved access to, and reduced cost of, internet services in Tuvalu.
# Processing URL: http://documents.worldbank.org/curated/en/387701526305722784/text/Marshall-Islands-PAD-05102018.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it mentions the use of a Financial Management Information System (FMIS) and the use of cloud-based architecture, an electronic document management system, and a website to capture citizen feedback.
# Processing URL: http://documents.worldbank.org/curated/en/986901551713827331/text/project-appraisal-document-pad-p166107-11262018-636805944190375925.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics such as digitization of government payments, mobile money providers, and financial literacy and awareness campaigns. These topics are discussed in order to promote greater financial inclusion and the adoption of transaction accounts in Mozambique.
# Processing URL: http://documents.worldbank.org/curated/en/459901622426523727/text/Tanzania-Higher-Education-for-Economic-Transformation-Project.txt
# is the document discussing digital topics? and why?
#  No, the document is not discussing digital topics because it is being processed or is not available.
# Processing URL: http://documents.worldbank.org/curated/en/421121552269865410/text/India-project-appraisal-document-pad-P166923-dated-11219-02152019-636878522486568458.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it mentions digitization, online budget portals, mobile applications, and other digital topics.
# Processing URL: http://documents.worldbank.org/curated/en/861811553264634792/text/PAD2949-PAD-PUBILC3-14-19-Final-IDA-R2019-0033-1.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics such as the implementation of a new FMIS, the use of digital signatures, the use of 'smart cash' debit cards, and the introduction of an e-learning platform.
# Processing URL: http://documents.worldbank.org/curated/en/981341624154457123/text/Somalia-Education-for-Human-Capital-Development-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it mentions virtual approaches, digital programming, and fit-for-purpose information and communications technology to deliver services.
# Processing URL: http://documents.worldbank.org/curated/en/103411620240414592/text/Senegal-Jobs-Economic-Transformation-and-Recovery-Program-for-Results-Project.txt
# is the document discussing digital topics? and why?
#  No, the document is not discussing digital topics because it is a page about an error with a document that is being processed or is not available.
# Processing URL: http://documents.worldbank.org/curated/en/828101641923162341/text/Benin-Vocational-Education-and-Entrepreneurship-for-Jobs-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics, such as digital skills programs, digitalization of the TVET sector, and the use of broadband pilot to support training services. These topics are discussed in order to reduce safety risks associated with training, reduce the use of consumables, and ensure business continuity in training and skills development systems.
# Processing URL: http://documents.worldbank.org/curated/en/499531654607601087/text/Lesotho-Competitiveness-and-Financial-Inclusion-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics, such as digital transformation, digital financial services, digital payments, digital technology adoption, and digital skills. These topics are discussed in order to support the viability and growth of MSMEs, increase financial inclusion and resilience, and enhance the scope and quality of business support services.
# Processing URL: http://documents.worldbank.org/curated/en/099320011172233739/text/BOSIB0a85b6abf0360b0840425cf1fcafcb.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it mentions digital solutions such as Treasury Management System (TMS) and Human Resource Management Information System (HRMIS). It also mentions topics such as training, change management, and data protection and privacy.
# Processing URL: http://documents.worldbank.org/curated/en/764921654609947116/text/Gambia-Tourism-Diversification-and-Resilience-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it mentions digital tools and channels, digital payment acceptance infrastructure, expansion of virtual presence, digital platforms, and technology required to upgrade a business process/product/service.
# Processing URL: http://documents.worldbank.org/curated/en/735741649092736225/text/West-Bank-and-Gaza-Second-Phase-of-the-Public-Financial-Management-Improvement-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it mentions digital databases, registries, and big data, as well as taxpayer e-services and e-services portals.
# Processing URL: http://documents.worldbank.org/curated/en/170591651867496926/text/Congo-Democratic-Republic-of-Empowering-Women-Entrepreneurs-and-Upgrading-MSMEs-for-Economic-Transformation-and-Jobs-in-DRC-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it mentions digital financial services, digital payments, and digital technologies. It also mentions the use of digital technologies to enhance the effectiveness of investment promotion activities.
# Processing URL: http://documents.worldbank.org/curated/en/099340008042231617/text/BOSIB0e9d0718e0c308cd701aacb49e2b47.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it mentions the use of new technologies and the digitalization of services, the use of artificial intelligence to identify "red flags" for fraud, and the adoption of best practices and models of green and sustainable procurement.
# Processing URL: http://documents.worldbank.org/curated/en/099950011182224372/text/P1788240ca3267060a6d404c5d40e14b77.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics such as ICT infrastructure upgrades, data security, and the technical capacity of IT staff. These topics are discussed in order to improve the existing information system and ICT workforce supporting the Social Protection System (SPS) in Iraq, and to help the GOI White Paper address challenges such as the need for a MOLSA social registry and ICT infrastructure upgrades.
# 3     1
# 15    1
# 18    1
# 20    0
# 23    1
# 25    1
# 52    1
# 64    0
# 69    1
# 70    1
# 75    1
# 84    1
# 85    1
# 88    1
# 89    1
# 91    1
# Name: txturl, dtype: int64

# %%
clement_dig_proj[clement_dig_proj['repnb']=="PAD4621"]['txturl'].apply(is_digital_project)
# Out:
# Processing URL: http://documents.worldbank.org/curated/en/828101641923162341/text/Benin-Vocational-Education-and-Entrepreneurship-for-Jobs-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics, such as digital skills programs, digitalization of the TVET sector, and the use of broadband pilot to support training services. These topics are discussed in order to reduce safety risks associated with training, reduce the use of consumables, and ensure business continuity in training and skills development systems.
# 69    1
# Name: txturl, dtype: int64

# %%
result_5
# Out:
# 5    0
# Name: txturl, dtype: int64

# %%
clement_dig_proj[clement_dig_proj['repnb']=="PAD2371"]['txturl']
# Out:
# 5    http://documents.worldbank.org/curated/en/6820...
# Name: txturl, dtype: object

# %%
print(clement_dig_proj[(clement_dig_proj['repnb']=="PAD3001")]["txturl"].iloc[0])
# Out:
# http://documents.worldbank.org/curated/en/421121552269865410/text/India-project-appraisal-document-pad-P166923-dated-11219-02152019-636878522486568458.txt

# %%
is_digital_project("http://documents.worldbank.org/curated/en/682051501466439748/text/PAD-final-sent-to-SECPO-June29-07112017.txt")
# Out:
# Processing URL: http://documents.worldbank.org/curated/en/682051501466439748/text/PAD-final-sent-to-SECPO-June29-07112017.txt
# 0

# %%
result_5
# Out:
# 5    0
# Name: txturl, dtype: int64

# %%
clement_dig_proj[clement_dig_proj['digital_project_q1']==0]["repnb"]
# Out:
# 3     PAD2696
# 15     126142
# 18    PAD3050
# 20    PAD3550
# 23    PAD3001
# 25    PAD2949
# 52    PAD3788
# 64    PAD4365
# 69    PAD4621
# 70    PAD4849
# 75     177898
# 84    PAD4876
# 85    PAD4840
# 88    PAD4960
# 89    PAD4944
# 91    PP5074
# Name: repnb, dtype: object

# %%
from tqdm import tqdm

# %%
from tqdm import tqdm

# This will wrap around the DataFrame apply and show progress
with tqdm(total=clement_dig_proj.shape[0]) as pbar:
    clement_dig_proj['digital_project_q2'] = clement_dig_proj['txturl'].apply(is_digital_project)
    pbar.update(1)
# Out:
#   0%|          | 0/92 [00:00<?, ?it/s]Created a chunk of size 1683, which is longer than the specified 1500
# Created a chunk of size 1571, which is longer than the specified 1500
# Created a chunk of size 1912, which is longer than the specified 1500
# Created a chunk of size 1762, which is longer than the specified 1500
# Created a chunk of size 1737, which is longer than the specified 1500
# Created a chunk of size 1647, which is longer than the specified 1500
# Created a chunk of size 1533, which is longer than the specified 1500
# Created a chunk of size 1580, which is longer than the specified 1500
# Created a chunk of size 1543, which is longer than the specified 1500
# Created a chunk of size 1701, which is longer than the specified 1500
# Created a chunk of size 1659, which is longer than the specified 1500
# Created a chunk of size 1781, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1767, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1805, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1767, which is longer than the specified 1500
# Created a chunk of size 1895, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1806, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1783, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1767, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1815, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1816, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1767, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1767, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1830, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1767, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1783, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1767, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1831, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1839, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1767, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1767, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1767, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1783, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1767, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1767, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1767, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1767, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1783, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1767, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1767, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1767, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1691, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1783, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1767, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1766, which is longer than the specified 1500
# Created a chunk of size 1766, which is longer than the specified 1500
# Created a chunk of size 1692, which is longer than the specified 1500
# Created a chunk of size 1743, which is longer than the specified 1500
#   1%|          | 1/92 [08:21<12:40:44, 501.59s/it]

# %%
sum(clement_dig_proj['digital_project_q2'])
# Out:
# 58

# %%
# Apply the function to each URL in the DataFrame
result = clement_dig_proj['txturl'].apply(is_digital_project)

# Split the result into two separate Series (one for the binary outcome, one for the response)
clement_dig_proj['digital_project_q3'], clement_dig_proj['response_text'] = zip(*result)
# Out:
# Processing URL: http://documents.worldbank.org/curated/en/406511503626440012/text/Moldova-MGSP-PAD-08032017.txt
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised APIConnectionError: Error communicating with OpenAI: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)).
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it is discussing the development of digital platforms, the use of mobile devices, the digitization of services, and the establishment of a shared technological program.
# Processing URL: http://documents.worldbank.org/curated/en/473751557713173311/text/Tonga-Digital-Government-Support-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it is discussing the World Bank's Tonga Digital Government Support Project, which focuses on digital platforms and building the Government's capacity for citizen-centered integrated digital public service delivery across sectors.
# Processing URL: http://documents.worldbank.org/curated/en/760111522698319785/text/Afghanista-Digital-CASA-Project-PAD2021-03092018.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it is discussing the Digital CASA Regional Program, which is focused on increasing access to more affordable internet, crowding in private investment in the ICT sector, and improving participating governments' capacity to deliver digital government services.
# Processing URL: http://documents.worldbank.org/curated/en/771141548558042678/text/Tuvalu-project-appraisal-document-pad-P159395Dec18-12182018-636841368206528813.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because the World Bank is actively engaged on the digital development agenda in the Pacific and is working to facilitate improved access to, and reduced cost of, internet services in Tuvalu.
# Processing URL: http://documents.worldbank.org/curated/en/900251527478271533/text/COTE-DIVOIRE-PADnew-05082018.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it mentions digital solutions, apps, electronic bill boards, data collection using mobile phones, satellite weather data, and decision support systems.
# Processing URL: http://documents.worldbank.org/curated/en/682051501466439748/text/PAD-final-sent-to-SECPO-June29-07112017.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it is discussing the Digitization of Implementation Monitoring and Public Procurement Project (DIMAPPP), which includes topics such as e-GP, Big Data, Open Contracting, and strategic communications.
# Processing URL: http://documents.worldbank.org/curated/en/485771622426544909/text/Tanzania-Digital-Tanzania-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it is discussing topics such as e-Government services, digital fora, digital platforms, digital trade, digital services and productivity platforms, and digital technologies.
# Processing URL: http://documents.worldbank.org/curated/en/365901592877911328/text/Bangladesh-Enhancing-Digital-Government-and-Economy-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics such as copyright, trademarks, patents, domain name protection, data protection, digital government services, digital economy, emerging digital technologies, and the Fourth Industrial Revolution. These topics are discussed in order to strengthen the legal and regulatory enabling environment to support the next wave of digital development.
# Processing URL: http://documents.worldbank.org/curated/en/771571528428669934/text/REGIONAL-INTEGRATION-CAS-AFRICArev-05152018.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics, such as cybercrime, electronic KYC, and electronic identification and trust services, as well as the use of digital technology to improve access to services such as education, health, and banking.
# Processing URL: http://documents.worldbank.org/curated/en/526901520046068044/text/MADAGASCAR-PAD1-02082018.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics. It discusses topics such as digital collection of taxes, digitalization of government payments and MFIs, and the use of mobile phones and the internet to offer financial services.
# Processing URL: http://documents.worldbank.org/curated/en/182571526306707865/text/Micronesia-PAD-05102018.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it mentions the use of a website for the DoFA to provide information on budget preparation stages, final budget, and quarterly updates on budget execution, as well as the use of social media tools to encourage regular information sharing and consultation among user groups.
# Processing URL: http://documents.worldbank.org/curated/en/669461500561422719/text/Uruguay-PAD-07132017.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics such as electronic transactions, data collection and sharing protocols, international interoperability, user-focused tool enhancements, and e-government services. These topics are discussed in the context of the Government's Digital Uruguay Agenda for 2020 and the Program for Improvement of Public Services and State-Citizen Interaction, which aim to lower transaction costs associated with citizen and business interaction with the government by developing horizontal tools for e-government service simplification and modernization.
# Processing URL: http://documents.worldbank.org/curated/en/237141562292095592/text/Benin-Digital-Rural-Transformation-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics such as regulatory aspects that govern electronic communications and digital financial services, electronic proof, e-identification and e-signature, trusted service providers, e-commerce, e-contract, personal data protection and treatment, cyber criminality and security, digital payments infrastructure, use of alternative data for credit reporting, financial consumer protection, financial literacy, and data protection, and identifying opportunities for the design and development of new applications using mobile phones and other devices.
# Processing URL: http://documents.worldbank.org/curated/en/288961560045670620/text/Peru-Improving-the-Performance-of-Non-Criminal-Justice-Services-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it mentions electronic case management systems, electronic access to cases, online judgements, mobile justice, electronic notification modules, and the transition to electronic files.
# Processing URL: http://documents.worldbank.org/curated/en/826531523301322820/text/Djibouti-Public-Admin-PAD-PAD2604-04062018.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it mentions the development of a digital platform, digital service delivery, an integrated and interoperable digital platform, a new IT system for tax administration, an interoperable digital platform, a Public Key Infrastructure (PKI), and an e-ID system.
# Processing URL: http://documents.worldbank.org/curated/en/387701526305722784/text/Marshall-Islands-PAD-05102018.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it mentions the use of a Financial Management Information System (FMIS) and the use of cloud-based architecture, an electronic document management system, and a website to capture citizen feedback.
# Processing URL: http://documents.worldbank.org/curated/en/479751528083037454/text/PAD-05152018.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it mentions the digital economy, IT-enabled businesses, telecom and broadband infrastructure, the 3G network, digital outputs, web-based or web-enabled business models, the Estonian X-Road, digital signatures, online payment options, and the shared technology infrastructure.
# Processing URL: http://documents.worldbank.org/curated/en/871621624932207081/text/Burundi-Skills-for-Jobs-Women-and-Youth-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it mentions the need for digital skills in the modern economy, the demand for digital skills from employers and students, and the limited supply and quality of digital skills training.
# Processing URL: http://documents.worldbank.org/curated/en/986901551713827331/text/project-appraisal-document-pad-p166107-11262018-636805944190375925.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics such as digitization of government payments, mobile money providers, and financial literacy and awareness campaigns. These topics are discussed in order to promote greater financial inclusion and the adoption of transaction accounts in Mozambique.
# Processing URL: http://documents.worldbank.org/curated/en/662311592667181272/text/Comoros-Financial-Inclusion-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it is discussing the development of a digital economy, digital payments, digital financial services, and the digitization of government payments.
# Processing URL: http://documents.worldbank.org/curated/en/459901622426523727/text/Tanzania-Higher-Education-for-Economic-Transformation-Project.txt
# is the document discussing digital topics? and why?
#  No, the document is not discussing digital topics because it is being processed or is not available.
# Processing URL: http://documents.worldbank.org/curated/en/858051551063626207/text/India-Chhattisgarh-Public-Financial-Management-and-Accountability-Program-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it mentions digitization, Dynamic Beneficiary Registry and Data Exchange Platform, and electronic/digital databases.
# Processing URL: http://documents.worldbank.org/curated/en/902181548039624564/text/Project-Appraisal-Document-PAD-Sierra-Leone-Financial-Inclusion-Project-P166601-12212018-636836184164440328.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it is discussing the digitization of government payments, the development of digital access points, and the use of mobile wallets and other digital payments products to increase financial inclusion.
# Processing URL: http://documents.worldbank.org/curated/en/421121552269865410/text/India-project-appraisal-document-pad-P166923-dated-11219-02152019-636878522486568458.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it mentions digitization, online budget portals, mobile applications, and other digital topics.
# Processing URL: http://documents.worldbank.org/curated/en/250181582340455479/text/Nigeria-Digital-Identification-for-Development-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it is discussing the development of a digital identification system, the legal and regulatory framework for electronic transactions, cybersecurity, and the implementation of a large-scale digital ID system.
# Processing URL: http://documents.worldbank.org/curated/en/861811553264634792/text/PAD2949-PAD-PUBILC3-14-19-Final-IDA-R2019-0033-1.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics such as the implementation of a new FMIS, the use of digital signatures, the use of 'smart cash' debit cards, and the introduction of an e-learning platform.
# Processing URL: http://documents.worldbank.org/curated/en/315991594519247904/text/Niger-Smart-Villages-for-Rural-Growth-and-Financial-Inclusion-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it focuses on digital literacy, digital transformation, digital finance, and digital addressing systems.
# Processing URL: http://documents.worldbank.org/curated/en/370621567389621226/text/Grenada-Digital-Government-for-Resilience-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it is discussing the development of digital government services and platforms, digital literacy skills, electronic payment systems, single sign-on digital identifier platforms, applications, dashboards, and other outreach activities for citizens and businesses to interact with the government, and protocols for service interruptions that may result from climate-induced events.
# Processing URL: http://documents.worldbank.org/curated/en/267241552269666297/text/Project-Appraisal-Document-PAD-SCALED-UP-P168115-revised-February-26-2019-02262019-636878520441412199.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics, such as digital ID systems, digital skills, and digital payments. It is doing so in order to support the implementation of a digital ID system in Somalia, as well as to promote financial inclusion and equitable access to economic resources.
# Processing URL: http://documents.worldbank.org/curated/en/903431556503441520/text/Afghanistan-Payments-Automation-and-Integration-of-Salaries-in-Afghanistan-PAISA-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics. It mentions digital payments, digital platforms, digital financial services, and digital financial inclusion. It also mentions surveys and agents of licensed financial institutions, which are related to digital topics.
# Processing URL: http://documents.worldbank.org/curated/en/831811560823331664/text/Tunisia-GovTech-Digital-Transformation-for-User-Centric-Public-Services-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics. It is discussing topics such as digital transformation, digital government, digital divide, and GovTech reforms.
# Processing URL: http://documents.worldbank.org/curated/en/342681614653755518/text/Mali-Promote-Access-to-Finance-Entrepreneurship-and-Employment-in-Mali-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it mentions digital transformation, digital platforms, digital strategies, agent banking, digital products, e-money, digital financial services, government payment digitization, and fintech development.
# Processing URL: http://documents.worldbank.org/curated/en/308971641932185582/text/Morocco-Public-Sector-Performance-ENNAJAA-Program-for-Results.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it mentions fully digitalized public services, increased access to and quality of open data, increased interoperability of public data and platforms for digitalized service delivery, law on digital administration, increased number of departments sharing and accessing data through the national interoperability platform, and improved access to online services.
# Processing URL: http://documents.worldbank.org/curated/en/434621601690509534/text/Madagascar-Digital-Governance-and-Identification-Management-System-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it is discussing the opportunities for digital transformation in Madagascar, the government's approach to digitalization, and the need for interoperability of government datasets and systems across government.
# Processing URL: http://documents.worldbank.org/curated/en/261151588384951057/text/Benin-Burkina-Faso-Togo-and-Niger-Second-Phase-of-West-Africa-Unique-Identification-for-Regional-Integration-and-Inclusion-WURI-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it is discussing the West Africa Unique Identification for Regional Integration and Inclusion Project, which is a technical project that involves the use of digital technologies.
# Processing URL: http://documents.worldbank.org/curated/en/996651598925686197/text/Georgia-Log-In-Georgia-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics such as international trade, tourism, education, health, digital skills, e-literacy, digital infrastructure, digital inclusion, and digital opportunities.
# Processing URL: http://documents.worldbank.org/curated/en/760461598666453706/text/Nigeria-Edo-Basic-Education-Sector-and-Skills-Transformation-Operation.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it is discussing digital skills training, digital technology skills, and digital skills and entrepreneurship training programs, which are all related to digital topics.
# Processing URL: http://documents.worldbank.org/curated/en/887341581303627383/text/Mexico-Modernization-of-Public-Financial-Management-Systems-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it mentions the need to upgrade the information technology supporting core information systems, the need to migrate the currently coexisting multiple information platforms to an integrated centralized solution, and the need to ensure operational stability, harmonize catalogues and workflows, and develop a comprehensive system architecture strategy as well as enhancing security standards.
# Processing URL: http://documents.worldbank.org/curated/en/913591595210515945/text/Cameroon-Secondary-Education-and-Skills-Development-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it mentions digital skills, digital infrastructure, websites and applications, and an integrated digital platform on training opportunities.
# Processing URL: http://documents.worldbank.org/curated/en/397091586570439508/text/Peru-Centralized-Emergency-Response-System-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it mentions digital technologies, digital software and hardware, geolocation policies, and interoperability of systems.
# Processing URL: http://documents.worldbank.org/curated/en/613581596247523870/text/Nigeria-Adolescent-Girls-Initiative-for-Learning-and-Empowerment-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it mentions digital literacy training, using digital technology, accessing online content, networking and collaborating, and online safety.
# Processing URL: http://documents.worldbank.org/curated/en/544751585015347579/text/Jordan-Youth-Technology-and-Jobs-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it focuses on expanding business and job opportunities in the digital sector, digital skills as one of key enablers for access to jobs, digital government services and payments, digital entrepreneurship, and digital transformation.
# Processing URL: http://documents.worldbank.org/curated/en/432601585596558171/text/Federated-States-of-Micronesia-Digital-Federated-States-of-Micronesia-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics such as digital circulation of images and videos, digital literacy training, digital government services, digital identity, and digital payments platforms. These topics are discussed in order to understand the relevance of the project to the Bank's twin goals of ending extreme poverty and boosting shared prosperity.
# Processing URL: http://documents.worldbank.org/curated/en/421681619316030132/text/Ethiopia-Ethiopia-Digital-Foundations-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it is discussing the Ethiopia Digital Foundations Project, which is focused on digital innovations and participation in the digital economy. It is discussing topics such as telecom sector reform, digital government, digital skills, digital start-ups, and internet access and use.
# Processing URL: http://documents.worldbank.org/curated/en/933721603977574627/text/Cabo-Verde-Digital-Cabo-Verde-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it is discussing the Digital Cabo Verde Project, which is focused on accelerating Cabo Verde's digital transformation.
# Processing URL: http://documents.worldbank.org/curated/en/473041622944887337/text/Uganda-Digital-Acceleration-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it is discussing the Digital Transformation Program (DTP) under Uganda's National Development Plan III, which aims to increase ICT penetration and use of ICT services for social and economic development. It also discusses the Digital Uganda Vision and the Digital Transformation for Africa initiative of the African Union, which aims to have every African individual, business, and government digitally enabled by 2030.
# Processing URL: http://documents.worldbank.org/curated/en/639311629138295811/text/Marshall-Islands-Digital-Republic-of-the-Marshall-Islands-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it is discussing digital government services, digital economy, digital infrastructure, digital applications, digital services, digital ID systems, and digital content.
# Processing URL: http://documents.worldbank.org/curated/en/848701593136915061/text/Dominica-Grenada-St-Lucia-St-Vincent-and-the-Grenadines-and-the-Organization-of-Eastern-Caribbean-States-Caribbean-Digital-Transformation-Project-Digital-Caribbean.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it is discussing digital connectivity, digital ecosystems, digital payments, digital platforms, digital technologies, digital devices, digital government infrastructure, digital identification systems, digital payment platforms, and digital document management.
# Processing URL: http://documents.worldbank.org/curated/en/961781641826916589/text/Congo-Democratic-Republic-of-Enhancing-Collection-of-Revenue-and-Expenditure-Management-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it mentions digital systems, digitalized systems, Integrated Financial Management Information System (IFMIS), e-procurement, and Digitalization Action Plan.
# Processing URL: http://documents.worldbank.org/curated/en/127181606851449191/text/Haiti-Digital-Acceleration-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it mentions digital skills, digital literacy, online safety, data governance, cybersecurity, and climate and DRM applications.
# Processing URL: http://documents.worldbank.org/curated/en/226281633117145206/text/Mozambique-Digital-Governance-and-Economy-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it is discussing topics such as digital transformation, digital government services, digital businesses, identity systems management, and the use of digital technologies for improved transparency, accountability, and service delivery.
# Processing URL: http://documents.worldbank.org/curated/en/873761583868077662/text/Costa-Rica-Fiscal-Management-Improvement-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it outlines the IT strategy behind the Project, examines the state of each system, and outlines options for system development. It also discusses the use of user-friendly tools, the generation of standardized reports, data mining, the application of machine learning models and real-time monitoring and analytics, telecommunications and infrastructure, cybersecurity, and tax systems.
# Processing URL: http://documents.worldbank.org/curated/en/981341624154457123/text/Somalia-Education-for-Human-Capital-Development-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it mentions virtual approaches, digital programming, and fit-for-purpose information and communications technology to deliver services.
# Processing URL: http://documents.worldbank.org/curated/en/099231001232324289/text/BOSIB02a30e05907508838065b63d56c19b.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it is discussing topics such as digital health interventions, digital public services development, digital sectoral regulation, spectrum management and allocation process, infrastructure sharing regulations, and strengthening the regulatory framework for digital financial services.
# Processing URL: http://documents.worldbank.org/curated/en/646761592256597274/text/West-Bank-and-Gaza-Technology-for-Youth-and-Jobs-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it is discussing the development impact of an IT project, the potential impact of cloud computing, and the use of digital technologies to increase working productivity and create jobs.
# Processing URL: http://documents.worldbank.org/curated/en/704361617300881789/text/St-Maarten-Digital-Government-Transformation-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it is discussing the Sint Maarten Digital Government Transformation Project, which includes topics such as digital payments, single sign-on, and mobile-based customer service feedback mechanisms.
# Processing URL: http://documents.worldbank.org/curated/en/657131611543704157/text/Mexico-National-Digital-Identity-System-to-Facilitate-Inclusion-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics such as data privacy, data security, biometric data, and digital ID systems. These topics are discussed in order to ensure adequate privacy and security for personal data, reduce identity theft, and increase financial inclusion.
# Processing URL: http://documents.worldbank.org/curated/en/542691624154434845/text/Uzbekistan-Tax-Administration-Reform-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics. It mentions the use of IT components, electronic services, automation, data recovery centers, and online feedback mechanisms.
# Processing URL: http://documents.worldbank.org/curated/en/099350001182233236/text/PAD04.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it is discussing the digital transformation of Cameroon, digital infrastructure investments, telecom market reform, digital access barriers, device affordability, digital literacy, and digital services.
# Processing URL: http://documents.worldbank.org/curated/en/709091640134304839/text/Rwanda-Digital-Acceleration-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it is discussing the World Bank's Digital Acceleration Project, which is focused on increasing digital access and inclusion, strengthening government capacity for digital services, and supporting digitally enabled businesses.
# Processing URL: http://documents.worldbank.org/curated/en/812291615393792444/text/West-Bank-and-Gaza-Digital-West-Bank-and-Gaza-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it is discussing the development of a digital economy in the West Bank and Gaza, including topics such as digital infrastructure, digital public platforms, digital businesses, digital skills, digital financial services, and access to e-services. It also discusses the legal and regulatory framework to support the digital transformation agenda, the creation of a Certificate Authority (CA) to issue digital certificates and digital signatures, public key infrastructure (PKI) aspects such as single sign on, user acceptance testing (UAT), and initiatives to improve access to e-services.
# Processing URL: http://documents.worldbank.org/curated/en/283361648600399938/text/Central-African-Republic-Public-Sector-Digital-Governance-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it is discussing digitalizing service delivery, digital identity ecosystems, and digital public services.
# Processing URL: http://documents.worldbank.org/curated/en/593891612224683734/text/Nicaragua-COVID-19-Education-Sector-Response-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it mentions the Mobile Digital Classrooms strategy, digital learning platforms, adaptive learning platforms, and the Caribbean Regional Communications Infrastructure Program (CARCIP).
# Processing URL: http://documents.worldbank.org/curated/en/236781624327270820/text/Madagascar-Economic-Transformation-for-Inclusive-Growth-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics. It mentions digital solutions for government to business services, digital tools and solutions, digital adoption, digital private sector, digital governance and identification management systems, digital technology for tourism, and digital agriculture initiatives.
# Processing URL: http://documents.worldbank.org/curated/en/103411620240414592/text/Senegal-Jobs-Economic-Transformation-and-Recovery-Program-for-Results-Project.txt
# is the document discussing digital topics? and why?
#  No, the document is not discussing digital topics. This document is being processed or is not available.
# Processing URL: http://documents.worldbank.org/curated/en/814561617415408733/text/Argentina-Digital-Inclusion-and-Innovation-in-Public-Services-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics such as digital financial services, digital government systems, e-filing, e-procurement, digital signature, and human resource management system.
# Processing URL: http://documents.worldbank.org/curated/en/099042523100539329/text/BOSIB09af1f3490ab0b2cb053b9c521680f.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics. It is discussing digital transformation principles, modernizing Dinas Dukcapil offices, establishing automated linkages for vital event reporting and population data updating, developing a digital archiving system for paper records, creating a responsive and interoperable platform, using open standards and preventing vendor and technology lock-in, protecting privacy and agency through system design, planning for financial and operational sustainability, socializing the digital ID application, developing a digital ID trust framework, and integrating population and other documents into the digital ID application.
# Processing URL: http://documents.worldbank.org/curated/en/116291646834371027/text/Cameroon-Adaptive-Safety-Nets-and-Economic-Inclusion-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it mentions the design and implementation of a digital payment system, the use of digital wallets and savings accounts, the use of a digital data collection and analysis tools, and the use of incentives to promote take-up of non-cash payment options.
# Processing URL: http://documents.worldbank.org/curated/en/099630005112275398/text/P175592002d4590208e3c034a9c0a165ad.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it mentions digital skills development, digital literacy, digital public services, digital delivery platforms, digital government services, and digital ID framework.
# Processing URL: http://documents.worldbank.org/curated/en/828101641923162341/text/Benin-Vocational-Education-and-Entrepreneurship-for-Jobs-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics, such as digital skills programs, digitalization of the TVET sector, and the use of broadband pilot to support training services. These topics are discussed in order to reduce safety risks associated with training, reduce the use of consumables, and ensure business continuity in training and skills development systems.
# Processing URL: http://documents.worldbank.org/curated/en/499531654607601087/text/Lesotho-Competitiveness-and-Financial-Inclusion-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics, such as digital transformation, digital financial services, digital payments, digital technology adoption, and digital skills. These topics are discussed in order to support the viability and growth of MSMEs, increase financial inclusion and resilience, and enhance the scope and quality of business support services.
# Processing URL: http://documents.worldbank.org/curated/en/099222003092324716/text/BOSIB04189961f0fd0b6c0059079d90f9e2.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it is discussing the use of digital technology for improved data collection, storage, and dissemination of statistical data. It is also discussing the use of IT solutions and digital data collection systems.
# Processing URL: http://documents.worldbank.org/curated/en/301741627956043619/text/Gabon-Digital-Gabon-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it is discussing topics such as communications and outreach plans, security of digital transactions, digital skills gaps, and digital government platforms.
# Processing URL: http://documents.worldbank.org/curated/en/852781653593751829/text/Kiribati-Digital-Government-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it is discussing the implementation of a digital ID system, digital services, automated authentication, document management systems, and digital services payment gateway.
# Processing URL: http://documents.worldbank.org/curated/en/938111649959522167/text/Ghana-Digital-Acceleration-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it is discussing the digital transformation of Ghana, digital services, digital capacity, digital back-office systems, and digital tools and systems.
# Processing URL: http://documents.worldbank.org/curated/en/099320011172233739/text/BOSIB0a85b6abf0360b0840425cf1fcafcb.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it mentions digital solutions such as Treasury Management System (TMS) and Human Resource Management Information System (HRMIS). It also mentions topics such as training, change management, and data protection and privacy.
# Processing URL: http://documents.worldbank.org/curated/en/207441655916156350/text/Burundi-Digital-Foundations-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it is discussing topics such as digital access, digital infrastructure, digital service frameworks, digital transformation, digital adoption, and digital payments.
# Processing URL: http://documents.worldbank.org/curated/en/656831656370652507/text/Mozambique-Digital-Acceleration-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it is discussing the use of digital technologies to improve operational efficiency and service delivery, digital infrastructure for government and private sector, data governance, data protection, cloud migration, and cybersecurity.
# Processing URL: http://documents.worldbank.org/curated/en/995101654266502751/text/Nepal-Digital-Nepal-Acceleration-DNA-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it is discussing digital foundations, digital literacy, digital skills, digital entrepreneurship, digital trust ecosystems, data centers, digital government functions and services, and digital inclusion.
# Processing URL: http://documents.worldbank.org/curated/en/846451654609750842/text/Mongolia-Second-Smart-Government-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it is discussing the adoption of digital technology in all sectors to drive economic growth, innovation, job creation, human capital development, and other means of diversifying and transforming the economy. It is also discussing digital skills training for GoM's civil servants, the development of a digital service standard, and the implementation of strategic integrated digital services.
# Processing URL: http://documents.worldbank.org/curated/en/099052623132039288/text/BOSIB04981acd800e08ea104a4baf88083b.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics, such as digitalizing critical tax administration processes, e-declaration and e-payment of corporate taxes, linking of the tax and customs information technology (IT) systems, e-services portal, electronic value added tax (VAT) billing devices, e-Balance Sheet platform, and digital human resource management administrative processes and services. These topics are discussed in order to improve transparency, reduce tax fraud, and increase efficiency.
# Processing URL: http://documents.worldbank.org/curated/en/349831646427383240/text/Armenia-Fourth-Public-Sector-Modernization-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it mentions advancements in digital government, digital infrastructure, digital signatures, digital documents, technical skills of public sector staff, digitalization process, information technology systems, government cloud, mobile government services, cloud computing, artificial intelligence, and other digital topics.
# Processing URL: http://documents.worldbank.org/curated/en/099030105092223190/text/P1770400f1e4f20c0b0060e64f16146fce.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics, such as data protection, cybersecurity, electronic transactions, and identification, in order to enable a scale-up of digital transactions while providing adequate safeguards to foster trust in the digital ecosystem.
# Processing URL: http://documents.worldbank.org/curated/en/779811655323104127/text/Sao-Tome-and-Principe-Digital-Sao-Tome-and-Principe-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics such as digital foundational laws, digital access and inclusion, data foundations for secure digital public services, digital payment systems, and digital ID and authentication.
# Processing URL: http://documents.worldbank.org/curated/en/764921654609947116/text/Gambia-Tourism-Diversification-and-Resilience-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it mentions digital tools and channels, digital payment acceptance infrastructure, expansion of virtual presence, digital platforms, and technology required to upgrade a business process/product/service.
# Processing URL: http://documents.worldbank.org/curated/en/735741649092736225/text/West-Bank-and-Gaza-Second-Phase-of-the-Public-Financial-Management-Improvement-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it mentions digital databases, registries, and big data, as well as taxpayer e-services and e-services portals.
# Processing URL: http://documents.worldbank.org/curated/en/340621654550658758/text/Lesotho-Pathways-to-Sustainable-Livelihoods-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it is discussing the implementation of a digital payments roadmap to facilitate the roll-out of digital payments across MoSD’s social assistance programs. It is also discussing the development of the broader digital payment systems architecture in Lesotho and the upgrading of the supporting necessary IT systems.
# Processing URL: http://documents.worldbank.org/curated/en/099051523173033620/text/BOSIB0ef18fc520100b4210f8b4287b16b4.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics such as digital financial services (DFS), digital payments, and digitalization of government payments and services. This is because digitalization can help increase uptake of DFS, reduce leakages and result in time and cost savings for the government, and help bring informal entrepreneurs and MSMEs into the formal economy.
# Processing URL: http://documents.worldbank.org/curated/en/170591651867496926/text/Congo-Democratic-Republic-of-Empowering-Women-Entrepreneurs-and-Upgrading-MSMEs-for-Economic-Transformation-and-Jobs-in-DRC-Project.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it mentions digital financial services, digital payments, and digital technologies. It also mentions the use of digital technologies to enhance the effectiveness of investment promotion activities.
# Processing URL: http://documents.worldbank.org/curated/en/099340008042231617/text/BOSIB0e9d0718e0c308cd701aacb49e2b47.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it mentions the use of new technologies and the digitalization of services, the use of artificial intelligence to identify "red flags" for fraud, and the adoption of best practices and models of green and sustainable procurement.
# Processing URL: http://documents.worldbank.org/curated/en/099030011152239001/text/BOSIB1dedfde1710df9141f3192fa15ec716f7f697.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics because it mentions digital solutions, digital infrastructure investments, strengthening data infrastructure, digital skills and technology, and digital technologies and applications.
# Processing URL: http://documents.worldbank.org/curated/en/099950011182224372/text/P1788240ca3267060a6d404c5d40e14b77.txt
# is the document discussing digital topics? and why?
#  Yes, the document is discussing digital topics such as ICT infrastructure upgrades, data security, and the technical capacity of IT staff. This is because the document is discussing the need for ICT infrastructure upgrades to improve the effectiveness of the Iraqi Social Protection System and to help the vulnerable cope with shocks.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\ALEXAN~1\AppData\Local\Temp/ipykernel_14004/2232552788.py in <module>
#       3
#       4 # Split the result into two separate Series (one for the binary outcome, one for the response)
# ----> 5 clement_dig_proj['digital_project_q3'], clement_dig_proj['response_text'] = zip(*result)
#
# TypeError: 'int' object is not iterable

# %%
result
# Out:
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1
#      ..
# 87    1
# 88    1
# 89    1
# 90    1
# 91    1
# Name: txturl, Length: 92, dtype: int64

# %%
clement_dig_proj['digital_project_q3'] = result

# %%
sum(clement_dig_proj['digital_project_q3'] )
# Out:
# 90

# %%
clement_dig_proj.shape
# Out:
# (92, 93)
